# %% [markdown]
# <a href="https://colab.research.google.com/github/tsm-mehmetakiftasoz/tsm_makif/blob/main/Gemini%20Ba%C4%9Flant%C4%B1s%C4%B1%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai
import google.generativeai as genai
import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
# 2. SABİTLERİN TANIMLANMASI (API Anahtarı dahil)
# !!! DİKKAT: API ANAHTARI KODA GÖMÜLMÜŞTÜR - GÜVENLİK RİSKİ !!!
GOOGLE_API_KEY = "AIzaSyCYZP7v4C46Y-3TV-IYCO65JWxVMphUAPs"
MODEL_NAME = 'gemini-2.5-flash'
SIFIRLAMA_SIFRESİ = "Mischief Managed."
SOZLESMELI_MESAJ = "Sohbeti Başlat" # İlk butonda yazacak

# %%
# API Yapılandırması
try:
    genai.configure(api_key=GOOGLE_API_KEY)
except Exception as e:
    print(f"❌ Yapılandırma Hatası: {e}")

# %%
# Global değişkenler
chat = None
output_area = widgets.Output() # Sohbet geçmişini tutmak için alan

def sohbeti_baslat_arayuz():
    """
    Sohbet oturumunu başlatır ve arayüz öğelerini oluşturur.
    """
    global chat, output_area

    # Sohbeti temizle ve yeniden başlat
    clear_output(wait=True)

    try:
        model = genai.GenerativeModel(MODEL_NAME)
        chat = model.start_chat(history=[])

        with output_area:
            print("-" * 50)
            print(f"✅ I solemnly swear that I am up to no good. (Model: {MODEL_NAME})")
            print("💡 Mesajınızı aşağıdaki kutuya yazıp 'Gönder'e tıklayın.")
            print(f"Çıkmak için: '{SIFIRLAMA_SIFRESİ}' yazın.")
            print("-" * 50)

    except Exception as e:
        with output_area:
            print(f"❌ Başlatma Hatası: {e}")
        return

# %%
    # Arayüz öğeleri
    metin_kutusu = widgets.Text(
        description='Mesajınız:',
        placeholder='Buraya yazın...',
        style={'description_width': 'initial'}
    )
    gonder_butonu = widgets.Button(description="Gönder")

# %%
def sohbeti_baslat_arayuz():
    """
    Sohbet oturumunu başlatır ve arayüz öğelerini oluşturur.
    """
    global chat, output_area

    # Sohbeti temizle ve yeniden başlat
    clear_output(wait=True)

    try:
        model = genai.GenerativeModel(MODEL_NAME)
        chat = model.start_chat(history=[])

        with output_area:
            print("-" * 50)
            print(f"✅ I solemnly swear that I am up to no good. (Model: {MODEL_NAME})")
            print("💡 Mesajınızı aşağıdaki kutuya yazıp 'Gönder'e tıklayın.")
            print(f"Çıkmak için: '{SIFIRLAMA_SIFRESİ}' yazın.")
            print("-" * 50)

    except Exception as e:
        with output_area:
            print(f"❌ Başlatma Hatası: {e}")
        return

# %%
    metin_kutusu = widgets.Text(
        description='Mesajınız:',
        placeholder='Buraya yazın...',
        style={'description_width': 'initial'}
    )

# %%
    gonder_butonu = widgets.Button(description="Gönder")

    # Düğme tıklandığında çalışacak fonksiyon
    def gonder_tusa_basildi(b):
        global chat
        kullanici_mesaji = metin_kutusu.value.strip()

        if not kullanici_mesaji:
            return

        # Output alanını kullanarak sohbeti güncelle
        with output_area:
            # Sıfırlama şifresi kontrolü
            if kullanici_mesaji == SIFIRLAMA_SIFRESİ:
                print("\n✅ Şifre doğru. Sohbet oturumu sonlandırıldı.")
                display(widgets.HTML('<hr>')) # Ayırıcı çizgi
                display(widgets.Label("Yeniden başlatmak için hücreyi tekrar çalıştırın."))

                # Arayüzü temizle ve durdur
                clear_output(wait=True)
                return

            print(f"\nSiz: {kullanici_mesaji}")

            try:
                # Mesajı Gemini'ye gönder ve yanıt al
                response = chat.send_message(kullanici_mesaji)
                print(f"Gemini: {response.text}")
            except Exception as e:
                print(f"❌ Hata: Mesaj gönderilemedi - {e}")

        # Metin kutusunu temizle
        metin_kutusu.value = ''

    # Düğme olayını bağlama
    gonder_butonu.on_click(gonder_tusa_basildi)

    # Arayüzü göster
    display(output_area, metin_kutusu, gonder_butonu)
# Out:
# Output()
# Text(value='', description='Mesajınız:', placeholder='Buraya yazın...', style=DescriptionStyle(description_wid…
# Button(description='Gönder', style=ButtonStyle())

# %%
sohbeti_baslat_arayuz()

# %%
import google.generativeai as genai
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

# API ayarı
genai.configure(api_key="AIzaSyCYZP7v4C46Y-3TV-IYCO65JWxVMphUAPs")

model = genai.GenerativeModel("gemini-2.5-flash")
chat = model.start_chat(history=[])

# Arayüz
output_area = widgets.Output(layout={
    'border': '3px solid #d97e07',
    'border_radius': '10px',
    'padding': '10px',
    'background_color': '#fac0c0',
    'max_height': '400px',
    'overflow_y': 'auto'
})

# Çok satırlı giriş alanı
metin_kutusu = widgets.Textarea(
    placeholder='💬 Mesajınızı yazın... (Enter = alt satır, Ctrl+Enter = gönder)',
    layout=widgets.Layout(width='80%', height='80px', padding='5px')
)

gonder_butonu = widgets.Button(
    description='🚀 Gönder',
    button_style='success',
    layout=widgets.Layout(width='20%', padding='5px', height='80px')
)

ui = widgets.VBox([output_area, widgets.HBox([metin_kutusu, gonder_butonu])])
display(ui)

# Mesaj gösterme fonksiyonu
def mesaj_goster(kimden, metin):
    renk = '#30D5C8' if kimden == 'Siz' else '#f5e36c'
    hizalama = 'right' if kimden == 'Siz' else 'left'
    with output_area:
        display(HTML(f"""
        <div style='text-align:{hizalama}; margin: 5px;'>
            <div style='display:inline-block; background:{renk}; border-radius:10px; padding:8px 12px; max-width:80%;'>
                <b>{kimden}:</b> {metin.replace('\n','<br>')}
            </div>
        </div>
        """))

# Gönderme fonksiyonu
def mesaj_gonder(_=None):
    kullanici_mesaji = metin_kutusu.value.strip()
    if not kullanici_mesaji:
        return
    mesaj_goster("Siz", kullanici_mesaji)
    metin_kutusu.value = ''
    try:
        yanit = chat.send_message(kullanici_mesaji)
        mesaj_goster("Gemini", yanit.text)
    except Exception as e:
        mesaj_goster("Sistem", f"Hata: {e}")

# Butona tıklama olayı
gonder_butonu.on_click(mesaj_gonder)

# 👇 Ctrl+Enter ile gönderme desteği
def klavye_kontrol(change):
    # ipywidgets'ta doğrudan key event yok, ama JS tarafına küçük bir listener ekleyebiliriz
    display(HTML("""
    <script>
    document.querySelector('textarea').addEventListener('keydown', function(e) {
        if (e.ctrlKey && e.key === 'Enter') {
            google.colab.kernel.invokeFunction('notebook.mesajGonder', [], {});
            e.preventDefault();
        }
    });
    </script>
    """))

# Colab tarafına Python fonksiyonu bağla
from google.colab import output
output.register_callback('notebook.mesajGonder', mesaj_gonder)

klavye_kontrol(None)
# Out:
# VBox(children=(Output(layout=Layout(border='3px solid #d97e07', max_height='400px', overflow_y='auto', padding…
#     <script>
#     document.querySelector('textarea').addEventListener('keydown', function(e) {
#         if (e.ctrlKey && e.key === 'Enter') {
#             google.colab.kernel.invokeFunction('notebook.mesajGonder', [], {});
#             e.preventDefault();
#         }
#     });
#     </script>

# %%
import google.generativeai as genai
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output
from google.colab import output
import time

# 🔑 API ayarı
genai.configure(api_key="AIzaSyCYZP7v4C46Y-3TV-IYCO65JWxVMphUAPs")

# 🌐 Başlangıç bağlantısı
bağlantı_durumu = widgets.HTML(
    "<b style='color:#ff9800;'>🔄 Gemini’ye bağlanılıyor...</b>"
)
display(bağlantı_durumu)
time.sleep(2)

try:
    #bağlantı_durumu.value
    model = genai.GenerativeModel("gemini-2.5-flash")
    chat = model.start_chat(history=[])
    bağlantı_durumu.value = """
    <b style='color:#4CAF50;'>✅ Gemini’ye başarıyla bağlanıldı.</b><br>
    <i>I solemnly swear that I am up to no good.</i>
    """
except Exception as e:
    bağlantı_durumu.value = f"<b style='color:red;'>❌ Bağlantı hatası: {e}</b>"

# 🪄 Arayüz
output_area = widgets.Output(layout={
    'border': '3px solid #d97e07',
    'border_radius': '10px',
    'padding': '10px',
    'background_color': '#fff8dc',
    'max_height': '400px',
    'overflow_y': 'auto'
})

metin_kutusu = widgets.Textarea(
    placeholder='💬 Mesajınızı yazın... (Enter = alt satır, Ctrl+Enter = gönder , sohbeti sonlandırmak için "mischief managed." yazın.)',
    layout=widgets.Layout(width='80%', height='80px', padding='5px')
)

gonder_butonu = widgets.Button(
    description='🚀 Gönder',
    button_style='success',
    layout=widgets.Layout(width='20%', height='80px', padding='5px')
)

ui = widgets.VBox([
    bağlantı_durumu,
    output_area,
    widgets.HBox([metin_kutusu, gonder_butonu])
])
display(ui)

# 🧙‍♂️ Mesaj gösterme
def mesaj_goster(kimden, metin):
    renk = '#30D5C8' if kimden == 'Siz' else '#f5e36c'
    hizalama = 'right' if kimden == 'Siz' else 'left'
    with output_area:
        display(HTML(f"""
        <div class='msg' style='text-align:{hizalama}; margin: 5px; opacity:1; transition:opacity 1.5s;'>
            <div style='display:inline-block; background:{renk}; border-radius:10px; padding:8px 12px; max-width:80%;'>
                <b>{kimden}:</b> {metin.replace('\\n','<br>')}
            </div>
        </div>
        """))

# 🧹 Sohbeti sonlandır
def sohbeti_kapat():
    metin_kutusu.disabled = True
    gonder_butonu.disabled = True
    bağlantı_durumu.value = """
    <b style='color:#9c27b0;'>✨ Mischief Managed. Sohbet sonlandırıldı.</b>
    """

# 💨 Fade-out tetikleme
def fade_out_mesajlar():
    display(HTML("""
    <script>
    let msgs = document.querySelectorAll('.msg');
    msgs.forEach(m => m.style.transition='opacity 2s');
    setTimeout(() => {
        msgs.forEach(m => m.style.opacity = 0);
    }, 500);
    </script>
    """))

# 🚀 Mesaj gönderme
def mesaj_gonder(_=None):
    kullanici_mesaji = metin_kutusu.value.strip()
    if not kullanici_mesaji:
        return

    mesaj_goster("Siz", kullanici_mesaji)
    metin_kutusu.value = ''

    # 🔒 Özel komutlar
    if kullanici_mesaji.strip() == "mischief managed.":
        fade_out_mesajlar()
        sohbeti_kapat()
        return


    try:
        yanit = chat.send_message(kullanici_mesaji)
        mesaj_goster("Gemini", yanit.text)
    except Exception as e:
        mesaj_goster("Sistem", f"Hata: {e}")

# 🎯 Gönderme olayları
gonder_butonu.on_click(mesaj_gonder)

# 🎹 Ctrl + Enter = Gönder
def js_klavye_dinleyici():
    display(HTML("""
    <script>
    document.querySelector('textarea').addEventListener('keydown', function(e) {
        if (e.shiftKey && e.key === 'Enter') {
            google.colab.kernel.invokeFunction('notebook.mesajGonder', [], {});
            e.preventDefault();
        }
    });
    </script>
    """))

output.register_callback('notebook.mesajGonder', mesaj_gonder)
js_klavye_dinleyici()
# Out:
# HTML(value="<b style='color:#ff9800;'>🔄 Gemini’ye bağlanılıyor...</b>")
# VBox(children=(HTML(value="\n    <b style='color:#4CAF50;'>✅ Gemini’ye başarıyla bağlanıldı.</b><br>\n    <i>I…
#     <script>
#     document.querySelector('textarea').addEventListener('keydown', function(e) {
#         if (e.shiftKey && e.key === 'Enter') {
#             google.colab.kernel.invokeFunction('notebook.mesajGonder', [], {});
#             e.preventDefault();
#         }
#     });
#     </script>

# %%
# Gerekli kütüphaneler
# !pip install -q google-genai
import google.generativeai as genai
import ipywidgets as widgets
from IPython.display import display, HTML
from google.colab import output
import time

# 🔑 API ayarı
genai.configure(api_key="AIzaSyCYZP7v4C46Y-3TV-IYCO65JWxVMphUAPs")

# 🌐 Başlangıç bağlantısı
bağlantı_durumu = widgets.HTML("<b style='color:#ff9800;'>🔄 Gemini’ye bağlanılıyor...</b>")

# 🪄 Arayüz
output_area = widgets.Output(layout={
    'border': '3px solid #d97e07',
    'border_radius': '10px',
    'padding': '10px',
    'background_color': '#fff8dc',
    'max_height': '400px',
    'overflow_y': 'auto'
})

metin_kutusu = widgets.Textarea(
    placeholder='💬 Mesajınızı yazın... (Enter = alt satır, Ctrl+Enter = gönder , sohbeti sonlandırmak için "mischief managed." yazın.)',
    layout=widgets.Layout(width='80%', height='80px', padding='5px')
)

gonder_butonu = widgets.Button(
    description='🚀 Gönder',
    button_style='success',
    layout=widgets.Layout(width='20%', height='80px', padding='5px')
)

ui = widgets.VBox([bağlantı_durumu, output_area, widgets.HBox([metin_kutusu, gonder_butonu])])
display(ui)

# 🔗 Gemini bağlantısı
try:
    model = genai.GenerativeModel("gemini-2.5-flash")
    chat = model.start_chat(history=[])
    bağlantı_durumu.value = """
    <b style='color:#ff9800;'>🔄 Gemini’ye bağlanılıyor...</b>
    """

    time.sleep(2)
    bağlantı_durumu.value = """
    <b style='color:#4CAF50;'>✅ Gemini’ye başarıyla bağlanıldı.</b><br>
    <i>I solemnly swear that I am up to no good.</i>
    """
except Exception as e:
    bağlantı_durumu.value = f"<b style='color:red;'>❌ Bağlantı hatası: {e}</b>"

# 🧙‍♂️ Mesaj gösterme
def mesaj_goster(kimden, metin):
    renk = '#30D5C8' if kimden == 'Siz' else '#f5e36c'
    hizalama = 'right' if kimden == 'Siz' else 'left'
    with output_area:
        display(HTML(f"""
        <div class='msg' style='text-align:{hizalama}; margin: 5px; opacity:1; transition:opacity 1.5s;'>
            <div style='display:inline-block; background:{renk}; border-radius:10px; padding:8px 12px; max-width:80%;'>
                <b>{kimden}:</b> {metin.replace('\\n','<br>')}
            </div>
        </div>
        """))

# 🧹 Sohbeti sonlandır
def sohbeti_kapat():
    metin_kutusu.disabled = True
    gonder_butonu.disabled = True
    bağlantı_durumu.value = "<b style='color:#9c27b0;'>✨Mischief managed. Otherwise, evil can see ..  👁️</b>"

# 💨 Fade-out tetikleme
def fade_out_mesajlar():
    display(HTML("""
    <script>
    let msgs = document.querySelectorAll('.msg');
    msgs.forEach(m => m.style.transition = 'opacity 2s');
    setTimeout(() => {
        msgs.forEach(m => m.style.opacity = 0);
    }, 500);
    </script>
    """))

# 🚀 Mesaj gönderme
def mesaj_gonder(_=None):
    kullanici_mesaji = metin_kutusu.value.strip()
    if not kullanici_mesaji:
        return

    mesaj_goster("Siz", kullanici_mesaji)
    metin_kutusu.value = ''

    # Sohbeti sonlandırma
    if kullanici_mesaji.lower() == "mischief managed.":
        fade_out_mesajlar()
        sohbeti_kapat()
        # Placeholder'ı İngilizce alıntıyla güncelle
        metin_kutusu.placeholder = 'Mischief managed. Otherwise, evil can see 👁️'
        time.sleep(3.5)
        output_area.clear_output()
        metin_kutusu.placeholder = ' '
        return

    try:
        yanit = chat.send_message(kullanici_mesaji)
        mesaj_goster("Gemini", yanit.text)
    except Exception as e:
        mesaj_goster("Sistem", f"Hata: {e}")

# 🎯 Gönderme olayları
gonder_butonu.on_click(mesaj_gonder)

# 🎹 Ctrl + Enter = Gönder
def js_klavye_dinleyici():
    display(HTML("""
    <script>
    document.querySelector('textarea').addEventListener('keydown', function(e) {
        if (e.ctrlKey && e.key === 'Enter') {
            google.colab.kernel.invokeFunction('notebook.mesajGonder', [], {});
            e.preventDefault();
        }
    });
    </script>
    """))

output.register_callback('notebook.mesajGonder', mesaj_gonder)
js_klavye_dinleyici()
# Out:
# VBox(children=(HTML(value="<b style='color:#ff9800;'>🔄 Gemini’ye bağlanılıyor...</b>"), Output(layout=Layout(b…
#     <script>
#     document.querySelector('textarea').addEventListener('keydown', function(e) {
#         if (e.ctrlKey && e.key === 'Enter') {
#             google.colab.kernel.invokeFunction('notebook.mesajGonder', [], {});
#             e.preventDefault();
#         }
#     });
#     </script>
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1010.33ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 2780.54ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1338.09ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1691.67ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1136.26ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1695.20ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 15525.51ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 8355.40ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 6063.30ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 6085.88ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 4016.03ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1540.70ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 6919.74ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1943.83ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1187.08ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1692.10ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1211.67ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 24757.30ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 3053.36ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1413.32ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1766.72ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 3456.85ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1539.65ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1821.20ms
#     <script>
#     let msgs = document.querySelectorAll('.msg');
#     msgs.forEach(m => m.style.transition = 'opacity 2s');
#     setTimeout(() => {
#         msgs.forEach(m => m.style.opacity = 0);
#     }, 500);
#     </script>
