# %% [markdown]
# <a href="https://colab.research.google.com/github/tsm-mehmetakiftasoz/tsm_makif/blob/main/%D0%B3%D0%BE%D1%82%D0%BE%D0%B2%D0%BE_ZMM059_%D0%BE%D1%82%D1%87%D0%B5%D1%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MM60
# MKVZ
# ME5A
# ZMM059
#
# ZMM059 RAPORLARINI BİRLEŞTİRMEK İÇİN OLUŞTURULDU . SAPDAN YILLARA GÖRE ZMM059 RAPORLARI ÇEKİP DEVAM EDİLEBİLİR. SAPDAN RAPORLARI ÇEKERKEN VARIANT MAKIF2 OLMALI TARİH SEÇİMİ PURCHASE DOC DATE OLMALI delivery completed indicatör 01 olmalı SAT REFERANSLI KISMI TÜMÜ OLMALI.
# ME5A RAPORLARI DA YILLARA GÖRE ÇEKİLMELİ variant "makif_report"
# EXCEL RAPORLARI ÇEKİLDİKTEN SONRA CSV FORMATINDA KAYDEDİLMELİ . YILLARA GÖRE ÇEKİLEN VERİLER ŞU ŞEKİLDE /content ALTINA KAYDEDİLMELİ.
#
# Tedarikçi isimleri için "MKVZ" kodunda "makif_report" variantı ile al
# Ru-Tr isimler için "mm60"ı kullan variant "makif_report"
#
#
# Создано для объединения отчетов ZMM059. Из SAP можно выгрузить отчеты ZMM059 по годам и продолжить работу. При выгрузке отчетов из SAP необходимо, чтобы вариант был MAKIF2, выбор даты должен быть Purchase Doc Date,Индикатор завершения доставки должен быть 01, а часть с ссылкой на SAT — выбрана "всё".
#
# После выгрузки отчетов в Excel их необходимо сохранить в формате CSV. Данные, выгруженные по годам, должны сохраняться в папке /content.
# Для наименований поставщиков используйте опцию «makif» в коде «MKVZ».
# Для названий на русском и турецком языках используйте вариант "mm60" "makif"
#
#
# ZMM059_2022.csv
# ZMM059_2023.csv
# ZMM059_2024-1.csv 01.01.2024-23.04.2024
# ZMM059_2024-2.csv 24.01.2024-15.07.2024
# ZMM059_2024-3.csv 16.07.2024-29.11.2024
# ZMM059_2024-4.csv 01.12.2024
# ZMM059_2025.csv
# tedarikci_isim.csv

# %%
# !pip install pandas
# !pip install xlsxwriter
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.11/dist-packages (3.2.3)

# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
df_me5a_2022 = pd.read_csv('/content/ME5A_2022.csv', sep=None, engine='python')
df_me5a_2023 = pd.read_csv('/content/ME5A_2023.csv', sep=None, engine='python')
df_me5a_2024 = pd.read_csv('/content/ME5A_2024.csv', sep=None, engine='python')
df_me5a_2025 = pd.read_csv('/content/ME5A_2022.csv', sep=None, engine='python')
# sep=None will automatically detect the delimiter
# engine='python' is slower but more robust for complex cases

# %%
#ilk sutuna yıl yazdırma
df_me5a_2022["ГОД"] = "2022"
cols = ["ГОД"] + [col for col in df_me5a_2022.columns if col != "ГОД"]
df_me5a_2022 = df_me5a_2022[cols]
#
df_me5a_2023["ГОД"] = "2023"
cols = ["ГОД"] + [col for col in df_me5a_2023.columns if col != "ГОД"]
df_me5a_2023 = df_me5a_2023[cols]
#
df_me5a_2024["ГОД"] = "2024"
cols = ["ГОД"] + [col for col in df_me5a_2024.columns if col != "ГОД"]
df_me5a_2024 = df_me5a_2024[cols]
#
df_me5a_2025["ГОД"] = "2025"
cols = ["ГОД"] + [col for col in df_me5a_2025.columns if col != "ГОД"]
df_me5a_2025 = df_me5a_2025[cols]

# %%
df_listesi = [df_me5a_2022, df_me5a_2023, df_me5a_2024,df_me5a_2025]
df_me5a_2022_2025 = pd.concat(df_listesi, ignore_index=True)

# %%
df_zmm059_2022 = pd.read_csv('/content/zmm059_2022.csv', sep=None, engine='python')
df_zmm059_2023 = pd.read_csv('/content/zmm059_2023.csv', sep=None, engine='python')
df_zmm059_2024_1 = pd.read_csv('/content/zmm059_2024_1.csv', sep=None, engine='python')
df_zmm059_2024_2 = pd.read_csv('/content/zmm059_2024_2.csv', sep=None, engine='python')
df_zmm059_2024_3 = pd.read_csv('/content/zmm059_2024_3.csv', sep=None, engine='python')
df_zmm059_2024_4 = pd.read_csv('/content/zmm059_2024_4.csv', sep=None, engine='python')
df_zmm059_2025 = pd.read_csv('/content/zmm059_2025.csv', sep=None, engine='python')
df_tedarikci_listesi = pd.read_csv('/content/tedarikci_isim.csv', sep=None, engine='python')
df_material_list = pd.read_csv('/content/material_list.csv', sep=None, engine='python')


# sep=None will automatically detect the delimiter
# engine='python' is slower but more robust for complex cases

# %%
#ilk sutuna yıl yazdırma
df_zmm059_2022["YIL"] = "2022"
cols = ["YIL"] + [col for col in df_zmm059_2022.columns if col != "YIL"]
df_zmm059_2022 = df_zmm059_2022[cols]
#
df_zmm059_2023["YIL"] = "2023"
cols = ["YIL"] + [col for col in df_zmm059_2023.columns if col != "YIL"]
df_zmm059_2023 = df_zmm059_2023[cols]
#
df_zmm059_2025["YIL"] = "2025"
cols = ["YIL"] + [col for col in df_zmm059_2025.columns if col != "YIL"]
df_zmm059_2025 = df_zmm059_2025[cols]
#
df_zmm059_2024_1["YIL"] = "2024"
cols = ["YIL"] + [col for col in df_zmm059_2024_1.columns if col != "YIL"]
df_zmm059_2024_1 = df_zmm059_2024_1[cols]
#
df_zmm059_2024_2["YIL"] = "2024"
cols = ["YIL"] + [col for col in df_zmm059_2024_2.columns if col != "YIL"]
df_zmm059_2024_2 = df_zmm059_2024_2[cols]
#
df_zmm059_2024_3["YIL"] = "2024"
cols = ["YIL"] + [col for col in df_zmm059_2024_3.columns if col != "YIL"]
df_zmm059_2024_3 = df_zmm059_2024_3[cols]
#
df_zmm059_2024_4["YIL"] = "2024"
cols = ["YIL"] + [col for col in df_zmm059_2024_4.columns if col != "YIL"]
df_zmm059_2024_4 = df_zmm059_2024_4[cols]

# %%
# DataFrame'leri bir listeye topla
dfs = [df_zmm059_2022, df_zmm059_2023, df_zmm059_2024_1, df_zmm059_2024_2, df_zmm059_2024_3, df_zmm059_2024_4, df_zmm059_2025]

# Hepsini birleştir
df_zmm059_2022_2025 = pd.concat(dfs, ignore_index=True)
df_zmm059_2022_2025_ = pd.concat(dfs, ignore_index=True)
# Kontrol için ilk satırlara bak
print(df_zmm059_2022_2025.tail(5))
# Out:
#          YIL  ﻿Документ закупки  Позиция Индикатор удаления неполн.  \
# 701711  2025       3.700000e+09       40                NaN     NaN
# 701712  2025       3.700000e+09       50                NaN     NaN
# 701713  2025       3.700000e+09       60                NaN     NaN
# 701714  2025       4.500000e+09       10                  L     NaN
# 701715  2025       4.500000e+09       20                  L     NaN
#
#             Материал        Заявка  Позиция заявки  \
# 701711        7006.0           NaN               0
# 701712        7000.0           NaN               0
# 701713        7000.0           NaN               0
# 701714  4500415852.0  2100003682.0              10
# 701715  4500415855.0  2100003682.0              20
#
#                                Материалы тур.  \
# 701711  Warehouse mechanization for materials
# 701712           Basic construction equipment
# 701713           Basic construction equipment
# 701714                                    NaN
# 701715             DİZEL  V/MAX  PETROL OFISI
#
#                                Материалы анг.  ...  \
# 701711  Warehouse mechanization for materials  ...
# 701712           Basic construction equipment  ...
# 701713           Basic construction equipment  ...
# 701714        GASOLINE 95 V/MAX  PETROL OFISI  ...
# 701715             DIESEL V/MAX  PETROL OFISI  ...
#
#        Остаток количества по счету Остаток суммы по счету  \
# 701711                           0                      0
# 701712                           0                      0
# 701713                           0                      0
# 701714                           0                      0
# 701715                           0                      0
#
#        Автор Внутреннего заказа Количество по счету.2  \
# 701711                      NaN                   NaN
# 701712                      NaN                   NaN
# 701713                      NaN                   NaN
# 701714                      NaN                   NaN
# 701715                      NaN                   NaN
#
#        Значок "поставка завершена"  Дата контракта  \
# 701711                         NaN             NaN
# 701712                         NaN             NaN
# 701713                         NaN             NaN
# 701714                         NaN             NaN
# 701715                         NaN             NaN
#
#        Дата вступления в силу контракта Дата окончания действия договора  \
# 701711                              NaN                              NaN
# 701712                              NaN                              NaN
# 701713                              NaN                              NaN
# 701714                              NaN                              NaN
# 701715                              NaN                              NaN
#
#        Склад  № комиссии
# 701711   NaN         NaN
# 701712   NaN         NaN
# 701713   NaN         NaN
# 701714  FUEL  2100003654
# 701715  FUEL  2100003654
#
# [5 rows x 65 columns]

# %%
df_calisilan = df_zmm059_2022_2025.copy()

# %%
df_calisilan.tail(5)
# Out:
#          YIL  ﻿Документ закупки  Позиция Индикатор удаления неполн.  \
# 701711  2025       3.700000e+09       40                NaN     NaN
# 701712  2025       3.700000e+09       50                NaN     NaN
# 701713  2025       3.700000e+09       60                NaN     NaN
# 701714  2025       4.500000e+09       10                  L     NaN
# 701715  2025       4.500000e+09       20                  L     NaN
#
#             Материал        Заявка  Позиция заявки  \
# 701711        7006.0           NaN               0
# 701712        7000.0           NaN               0
# 701713        7000.0           NaN               0
# 701714  4500415852.0  2100003682.0              10
# 701715  4500415855.0  2100003682.0              20
#
#                                Материалы тур.  \
# 701711  Warehouse mechanization for materials
# 701712           Basic construction equipment
# 701713           Basic construction equipment
# 701714                                    NaN
# 701715             DİZEL  V/MAX  PETROL OFISI
#
#                                Материалы анг.  ...  \
# 701711  Warehouse mechanization for materials  ...
# 701712           Basic construction equipment  ...
# 701713           Basic construction equipment  ...
# 701714        GASOLINE 95 V/MAX  PETROL OFISI  ...
# 701715             DIESEL V/MAX  PETROL OFISI  ...
#
#        Остаток количества по счету Остаток суммы по счету  \
# 701711                           0                      0
# 701712                           0                      0
# 701713                           0                      0
# 701714                           0                      0
# 701715                           0                      0
#
#        Автор Внутреннего заказа Количество по счету.2  \
# 701711                      NaN                   NaN
# 701712                      NaN                   NaN
# 701713                      NaN                   NaN
# 701714                      NaN                   NaN
# 701715                      NaN                   NaN
#
#        Значок "поставка завершена"  Дата контракта  \
# 701711                         NaN             NaN
# 701712                         NaN             NaN
# 701713                         NaN             NaN
# 701714                         NaN             NaN
# 701715                         NaN             NaN
#
#        Дата вступления в силу контракта Дата окончания действия договора  \
# 701711                              NaN                              NaN
# 701712                              NaN                              NaN
# 701713                              NaN                              NaN
# 701714                              NaN                              NaN
# 701715                              NaN                              NaN
#
#        Склад  № комиссии
# 701711   NaN         NaN
# 701712   NaN         NaN
# 701713   NaN         NaN
# 701714  FUEL  2100003654
# 701715  FUEL  2100003654
#
# [5 rows x 65 columns]

# %%
df_calisilan["B3-B3POZ"] = (
    df_calisilan["Заявка"].astype(str) + "_" + df_calisilan["Позиция заявки"].astype(str)
)

# %%
df_me5a_2022_2025["B3-B3POZ"] = (
    df_me5a_2022_2025["﻿Заявка"].astype(str) + "_" + df_me5a_2022_2025["Позиция заявки"].astype(str)
)

# %%
df_me5a_2022_2025.head()
# Out:
#     ГОД     ﻿Заявка  Позиция заявки      Материал  Индикатор удаления  \
# 0  2022  2200000016              10  4.500082e+09               False
# 1  2022  2200000016              20  4.500128e+09               False
# 2  2022  2100000001              10  4.500179e+09               False
# 3  2022  2100000001              30  4.500179e+09               False
# 4  2022  2200000051              10  4.500130e+09                True
#
#    Затребовал Индик. выдачи Дата заявки Группа закупок Дата изменения  ...  \
# 0       DUMMY             2  20.07.2022            T01      2.10.2023  ...
# 1       DUMMY             2  20.07.2022            T01      2.10.2023  ...
# 2        MC01             2  20.07.2022            T01     21.01.2023  ...
# 3        MC01             2  20.07.2022            T01     21.01.2023  ...
# 4  Kukshin E.             X  22.07.2022            001     28.01.2025  ...
#
#    Вид документа  Статус обработки Индикатор создания  Стратегия деблокир.  \
# 0           ZINT                 A                  R                   A3
# 1           ZINT                 A                  R                   A3
# 2           ZDIR                 N                  R                   B3
# 3           ZDIR                 N                  R                   B3
# 4           ZINT                 B                  R                   S1
#
#   НДП-материал Номер потребности Объем дефицита Тип даты поставки  \
# 0          NaN           O.SONAR              0                 D
# 1          NaN           O.SONAR              0                 D
# 2          NaN               NaN              0                 D
# 3          NaN               NaN          0,000                 D
# 4          NaN         E.KUKSHIN              0                 D
#
#   Дата деблокирования       B3-B3POZ
# 0           2.10.2023  2200000016_10
# 1          16.11.2023  2200000016_20
# 2          17.08.2022  2100000001_10
# 3          17.08.2022  2100000001_30
# 4          20.12.2024  2200000051_10
#
# [5 rows x 39 columns]

# %%
df_calisilan.rename(columns={'﻿Документ закупки': 'Документ_закупки'}, inplace=True)
df_calisilan.rename(columns={'YIL': 'ГОД'}, inplace=True)
df_calisilan.columns.values[2] = "Зп_Поз"
df_tedarikci_listesi.rename(columns={'kod': 'Поставщик'}, inplace=True)

# %%
df_calisilan.head(5)
# Out:
#     ГОД  Документ_закупки  Зп_Поз Индикатор удаления неполн. Материал  \
# 0  2022               NaN       0                NaN     NaN      NaN
# 1  2022               NaN       0                NaN     NaN      NaN
# 2  2022               NaN       0                NaN     NaN      NaN
# 3  2022               NaN       0                NaN     NaN      NaN
# 4  2022               NaN       0                NaN     NaN      NaN
#
#        Заявка  Позиция заявки Материалы тур. Материалы анг.  ...  \
# 0  2200000578            1890            NaN            NaN  ...
# 1  2200000578            1880            NaN            NaN  ...
# 2  2200000578            1900            NaN            NaN  ...
# 3  2200000578            1910            NaN            NaN  ...
# 4  2200000578            1870            NaN            NaN  ...
#
#   Остаток суммы по счету Автор Внутреннего заказа Количество по счету.2  \
# 0                  0,000                      NaN                   NaN
# 1                  0,000                      NaN                   NaN
# 2                  0,000                      NaN                   NaN
# 3                  0,000                      NaN                   NaN
# 4                  0,000                      NaN                   NaN
#
#   Значок "поставка завершена" Дата контракта  \
# 0                         NaN            NaN
# 1                         NaN            NaN
# 2                         NaN            NaN
# 3                         NaN            NaN
# 4                         NaN            NaN
#
#    Дата вступления в силу контракта Дата окончания действия договора Склад  \
# 0                               NaN                              NaN   NaN
# 1                               NaN                              NaN   NaN
# 2                               NaN                              NaN   NaN
# 3                               NaN                              NaN   NaN
# 4                               NaN                              NaN   NaN
#
#   № комиссии         B3-B3POZ
# 0        NaN  2200000578_1890
# 1        NaN  2200000578_1880
# 2        NaN  2200000578_1900
# 3        NaN  2200000578_1910
# 4        NaN  2200000578_1870
#
# [5 rows x 66 columns]

# %% [markdown]
# Buradan sonra boş pozisyonları siliyoruz.
# С этого момента мы удаляем вакантные должности.

# %%
adetler = df_calisilan["B3-B3POZ"].value_counts()

# %%
mukerrer_kodlar = adetler[adetler > 1].index

# %%
silinmesi_gerekenler = df_calisilan[
    (df_calisilan["B3-B3POZ"].isin(mukerrer_kodlar)) &
    (df_calisilan["Документ_закупки"].isna())

]

# %%
df_calisilan = df_calisilan.drop(silinmesi_gerekenler.index)

# %%
print(f"Kalan satır sayısı df_calısılan : {len(df_calisilan)}")
print(f"Kalan satır sayısı df_zmm059_2022_2025: {len(df_zmm059_2022_2025)}") #burada df i değşitirmek gerek
# Out:
# Kalan satır sayısı df_calısılan : 463022
# Kalan satır sayısı df_zmm059_2022_2025: 701716

# %%
df_calisilan
# Out:
#          ГОД  Документ_закупки  Зп_Поз Индикатор удаления неполн.  \
# 0       2022               NaN       0                NaN     NaN
# 1       2022               NaN       0                NaN     NaN
# 2       2022               NaN       0                NaN     NaN
# 3       2022               NaN       0                NaN     NaN
# 4       2022               NaN       0                NaN     NaN
# ...      ...               ...     ...                ...     ...
# 701711  2025      3.700000e+09      40                NaN     NaN
# 701712  2025      3.700000e+09      50                NaN     NaN
# 701713  2025      3.700000e+09      60                NaN     NaN
# 701714  2025      4.500000e+09      10                  L     NaN
# 701715  2025      4.500000e+09      20                  L     NaN
#
#             Материал        Заявка  Позиция заявки  \
# 0                NaN    2200000578            1890
# 1                NaN    2200000578            1880
# 2                NaN    2200000578            1900
# 3                NaN    2200000578            1910
# 4                NaN    2200000578            1870
# ...              ...           ...             ...
# 701711        7006.0           NaN               0
# 701712        7000.0           NaN               0
# 701713        7000.0           NaN               0
# 701714  4500415852.0  2100003682.0              10
# 701715  4500415855.0  2100003682.0              20
#
#                                Материалы тур.  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 701711  Warehouse mechanization for materials
# 701712           Basic construction equipment
# 701713           Basic construction equipment
# 701714                                    NaN
# 701715             DİZEL  V/MAX  PETROL OFISI
#
#                                Материалы анг.  ... Остаток суммы по счету  \
# 0                                         NaN  ...                  0,000
# 1                                         NaN  ...                  0,000
# 2                                         NaN  ...                  0,000
# 3                                         NaN  ...                  0,000
# 4                                         NaN  ...                  0,000
# ...                                       ...  ...                    ...
# 701711  Warehouse mechanization for materials  ...                      0
# 701712           Basic construction equipment  ...                      0
# 701713           Basic construction equipment  ...                      0
# 701714        GASOLINE 95 V/MAX  PETROL OFISI  ...                      0
# 701715             DIESEL V/MAX  PETROL OFISI  ...                      0
#
#        Автор Внутреннего заказа Количество по счету.2  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# ...                         ...                   ...
# 701711                      NaN                   NaN
# 701712                      NaN                   NaN
# 701713                      NaN                   NaN
# 701714                      NaN                   NaN
# 701715                      NaN                   NaN
#
#        Значок "поставка завершена" Дата контракта  \
# 0                              NaN            NaN
# 1                              NaN            NaN
# 2                              NaN            NaN
# 3                              NaN            NaN
# 4                              NaN            NaN
# ...                            ...            ...
# 701711                         NaN            NaN
# 701712                         NaN            NaN
# 701713                         NaN            NaN
# 701714                         NaN            NaN
# 701715                         NaN            NaN
#
#         Дата вступления в силу контракта Дата окончания действия договора  \
# 0                                    NaN                              NaN
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
# ...                                  ...                              ...
# 701711                               NaN                              NaN
# 701712                               NaN                              NaN
# 701713                               NaN                              NaN
# 701714                               NaN                              NaN
# 701715                               NaN                              NaN
#
#        Склад  № комиссии         B3-B3POZ
# 0        NaN         NaN  2200000578_1890
# 1        NaN         NaN  2200000578_1880
# 2        NaN         NaN  2200000578_1900
# 3        NaN         NaN  2200000578_1910
# 4        NaN         NaN  2200000578_1870
# ...      ...         ...              ...
# 701711   NaN         NaN            nan_0
# 701712   NaN         NaN            nan_0
# 701713   NaN         NaN            nan_0
# 701714  FUEL  2100003654  2100003682.0_10
# 701715  FUEL  2100003654  2100003682.0_20
#
# [463022 rows x 66 columns]

# %%
df_calisilan.sample(5, random_state=13)
# Out:
#          ГОД  Документ_закупки  Зп_Поз Индикатор удаления неполн.  \
# 630073  2025               NaN       0                NaN     NaN
# 396586  2024      3.100007e+09      10                NaN     NaN
# 694298  2025      3.100013e+09      70                NaN     NaN
# 448225  2024      3.100008e+09    1400                NaN     NaN
# 687157  2025      3.100013e+09    1730                NaN     NaN
#
#             Материал        Заявка  Позиция заявки  \
# 630073           NaN  2200014432.0             780
# 396586  4500284126.0  2200007751.0              30
# 694298  4500486429.0  9900003657.0             120
# 448225  4500293120.0  9900000147.0           22710
# 687157  4500399892.0  9900002023.0             670
#
#                              Материалы тур.  \
# 630073                                  NaN
# 396586  AKU.0120.00USY.0.KZ.LC0002 PF1(F11)
# 694298                                  NaN
# 448225    AKU.0120.00USY.0.KM.LC0030 VB6-86
# 687157                                  NaN
#
#                              Материалы анг.  ... Остаток суммы по счету  \
# 630073                                  NaN  ...                  0,000
# 396586  AKU.0120.00USY.0.KZ.LC0002 PF1(F11)  ...              6.442,010
# 694298     AKU.0120.12UBN.0.AR.LC0001 Pos.7  ...              1.832,460
# 448225    AKU.0120.00USY.0.KM.LC0030 VB6-86  ...                 92,280
# 687157      AKU.0179.00UKU.0.KM.TB0001.L6/1  ...            174.399,300
#
#        Автор Внутреннего заказа Количество по счету.2  \
# 630073                      NaN                   NaN
# 396586                      NaN                   NaN
# 694298                      NaN                   NaN
# 448225                      NaN                   NaN
# 687157                      NaN                   NaN
#
#        Значок "поставка завершена" Дата контракта  \
# 630073                         NaN            NaN
# 396586                           X            NaN
# 694298                           X            NaN
# 448225                           X            NaN
# 687157                           X            NaN
#
#         Дата вступления в силу контракта Дата окончания действия договора  \
# 630073                               NaN                              NaN
# 396586                               NaN                              NaN
# 694298                               NaN                              NaN
# 448225                               NaN                              NaN
# 687157                               NaN                              NaN
#
#        Склад № комиссии            B3-B3POZ
# 630073   NaN        NaN    2200014432.0_780
# 396586   NaN  ICEND2023     2200007751.0_30
# 694298   NaN  90VFA2025    9900003657.0_120
# 448225   NaN  TSM072498  9900000147.0_22710
# 687157   NaN  90VFA2025    9900002023.0_670
#
# [5 rows x 66 columns]

# %%
for i, col in enumerate(df_calisilan.columns):
    print(f"{i}: {col}")
# Out:
# 0: ГОД
# 1: Документ_закупки
# 2: Зп_Поз
# 3: Индикатор удаления
# 4: неполн.
# 5: Материал
# 6: Заявка
# 7: Позиция заявки
# 8: Материалы тур.
# 9: Материалы анг.
# 10: Инвентарный номер в SAS
# 11: Количество ЗП
# 12: Минимальная цена ЗП
# 13: Минимальная цена ЗП.1
# 14: Минимальная цена ЗП.2
# 15: Единица ЗП
# 16: Цена нетто ЗП
# 17: Итого цена нетто
# 18: Валюта ЗП
# 19: Вид докум. закупки
# 20: Дата создания
# 21: Дата поставки
# 22: Дата доставки, одобренная Поставщиком
# 23: Группа закупок
# 24: Название ГрЗакупок
# 25: БЕ
# 26: Название фирмы
# 27: Закуп. организация
# 28: Название ЗакупОрг
# 29: Завод
# 30: Имя 1
# 31: Поставщик
# 32: Группа материалов
# 33: Название группы
# 34: Краткий текст
# 35: Создал
# 36: Вид докум. закупки.1
# 37: Обозначение ВидДокум
# 38: Дата создания.1
# 39: Создал.1
# 40: Группа закупок.1
# 41: Название ГрЗакупок.1
# 42: ЕИ заказа на постав.
# 43: Единица цены
# 44: Цена заказа нетто
# 45: Стоимость брутто
# 46: Валюта
# 47: Недопоставленное количество
# 48: Количество поставки
# 49: Сумма брутто
# 50: Валюта.1
# 51: Количество по счету
# 52: Дата проводки
# 53: Количество по счету.1
# 54: Валюта.2
# 55: Остаток количества по счету
# 56: Остаток суммы по счету
# 57: Автор Внутреннего заказа
# 58: Количество по счету.2
# 59: Значок "поставка завершена"
# 60: Дата контракта
# 61: Дата вступления в силу контракта
# 62: Дата окончания действия договора
# 63: Склад
# 64: № комиссии
# 65: B3-B3POZ

# %% [markdown]
# alttaki kodu sileceğiz

# %%
# Silmek istediğin sütunların index (pozisyon) numaraları
#sil_indexler = [8,9,10,11,12,13,17,27,28,29,33,43,44,55,73,74,79,80,81,82,
   #             83,84,85,86,87,88,89,90,91,93,94,95,96,97,98,99,100,101,102
    #            ]  # 0'dan başlar, örneğin 2., 4. ve 6. sütun

# Yeni DataFrame'i bu sütunlar hariç oluştur
#df_calisilan = df_calisilan.drop(df_calisilan.columns[sil_indexler], axis=1)

# %%
# Sütunları silme
#df_zmm059_2022_2025_sutunsuz = df_zmm059_2022_2025.drop(columns=["Запрос", "Позиция.1","Долгосрочный договор",
#"Позиция ОснДоговора","TR Наименование","RU Наименование","Номер проекта в SAS",
 #"Обозначение ВидДокум","Условие платежа","Срок платежа","Задержка","Вид материала",
#"ДоговорнКоличество","Номенклатура по договору", "Наименование номенклатуры по договору",
#"Сумма договору", "Договорная цена нетто","Имя клиента","Дата доставки во Внутреннем заказ",
#"Дата заявки","PR / GR (%)","PR / PO (%)","Вид документа","Внутр. заказ заводу-изготовителю",
#  "Автор ЗП в 1С" ,"Тип создания","Склад" ,"Обозначение склада","Requester" ,"Групповой номер",
 #   "Телефон", "Обозначение вида материал" ,"Группа закупок",
# "Затребовал","Количество во Внутреннем заказе","Единица измерения","№ комиссии" ,
# "№ ЗП в 1С" ])

# %%
df_calisilan.sample(5, random_state=2)
# Out:
#          ГОД  Документ_закупки  Зп_Поз Индикатор удаления неполн.  \
# 585732  2024      3.100011e+09      30                NaN     NaN
# 686480  2025      3.100013e+09      30                NaN     NaN
# 243314  2023      3.100005e+09      60                NaN     NaN
# 260185  2023      3.100005e+09    4280                NaN     NaN
# 64475   2022      3.400012e+09     110                NaN     NaN
#
#             Материал        Заявка  Позиция заявки  \
# 585732    4500448944  9900002994.0              20
# 686480  4500079855.0  2200012101.0              10
# 243314  4500240237.0  2200005632.0              60
# 260185  4500230106.0  2200005042.0            3590
# 64475   4500069106.0           NaN               0
#
#                                   Материалы тур.  \
# 585732     0120.00USY.0.KM.LC0007 B1-104/pos.327
# 686480  SU TUTUCU BANDI AQUASTOP DR-210/30 PVC-P
# 243314          MAPA KİLİT 8,5Т DIN 832 TİP G210
# 260185          10UJA.KAA.TM.TB0202.22/46.1-M211
# 64475            AKU.0120.20UCB.0.KZ.LC0002 TD17
#
#                                 Материалы анг.  ... Остаток суммы по счету  \
# 585732   0120.00USY.0.KM.LC0007 B1-104/pos.327  ...              4.508,310
# 686480    HYDROSPONSE AQUASTOP DR-210/30 PVC-P  ...                      0
# 243314  RIGGING BRACKET 8,5Т DIN 832 TYPE G210  ...                  1,720
# 260185        10UJA.KAA.TM.TB0202.22/46.1-M211  ...                106,510
# 64475                                      NaN  ...                  0,000
#
#        Автор Внутреннего заказа Количество по счету.2  \
# 585732                      NaN                   NaN
# 686480                      NaN                   NaN
# 243314                      NaN                   NaN
# 260185                      NaN                   NaN
# 64475              Tufan Ismail       Inanc Karabulut
#
#        Значок "поставка завершена" Дата контракта  \
# 585732                           X            NaN
# 686480                         NaN     16.04.2025
# 243314                           X     23.10.2023
# 260185                           X      1.05.2023
# 64475                          NaN            NaN
#
#         Дата вступления в силу контракта Дата окончания действия договора  \
# 585732                               NaN                              NaN
# 686480                        16.04.2025                       31.12.9999
# 243314                        23.10.2023                       31.12.2023
# 260185                         1.05.2023                       31.01.2024
# 64475                                NaN                              NaN
#
#        Склад № комиссии           B3-B3POZ
# 585732   NaN  90VFA2024    9900002994.0_20
# 686480   NaN    АК-Р-76    2200012101.0_10
# 243314   NaN    AKMM438    2200005632.0_60
# 260185   NaN    AKEM144  2200005042.0_3590
# 64475    NaN      empty              nan_0
#
# [5 rows x 66 columns]

# %%
df_calisilan["ГОД"] = df_calisilan["ГОД"].astype(str)  # string'e çevirmek istersen

# Replace NaN values with a placeholder integer (e.g., 0) before converting to int
df_calisilan["Документ_закупки"] = df_calisilan["Документ_закупки"].fillna(0).astype(int).astype(str)

# %%
df_tedarikci_listesi.head(5)
# Out:
#   ﻿Кредитор                      Имя поставщика Страна  \
# 0      2000   IC İÇTAŞ İNŞAAT SAN. VE TİC. A.Ş.     TR
# 1      2000   IC İÇTAŞ İNŞAAT SAN. VE TİC. A.Ş.     TR
# 2      2000   IC İÇTAŞ İNŞAAT SAN. VE TİC. A.Ş.     TR
# 3      2000   IC İÇTAŞ İNŞAAT SAN. VE TİC. A.Ş.     TR
# 4      2020  IC IÇTAS ENDÜSTRIYEL BORU LOJISTIK     TR
#
#   Центральная метка удаления  Закуп. организация  \
# 0                        NaN                2990
# 1                        NaN                2991
# 2                        NaN                2992
# 3                        NaN                2993
# 4                        NaN                2990
#
#   Метка удаления для закупочн. организации
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN

# %%
def temizle_ve_cevir(x):
    try:
        return str(int(float(x)))
    except:
        return str(x)

# %%
df_calisilan["Поставщик"] = df_calisilan["Поставщик"].apply(temizle_ve_cevir)

# %%
# Tedarikçi sözlüğünü yine string anahtarlara göre oluştur
tedarikci_dict = dict(zip(df_tedarikci_listesi.iloc[:, 0].astype(str), df_tedarikci_listesi.iloc[:, 1]))

# Eşleştirme
df_calisilan["имя_поставщика"] = df_calisilan["Поставщик"].map(tedarikci_dict)

# %%
df_me5a_2022_2025["Материал"] = df_me5a_2022_2025["Материал"].apply(temizle_ve_cevir)

# %%
df_calisilan["Материал"] = df_calisilan["Материал"].apply(temizle_ve_cevir)

# %%
df_calisilan.head()
# Out:
#     ГОД Документ_закупки  Зп_Поз Индикатор удаления неполн. Материал  \
# 0  2022                0       0                NaN     NaN      nan
# 1  2022                0       0                NaN     NaN      nan
# 2  2022                0       0                NaN     NaN      nan
# 3  2022                0       0                NaN     NaN      nan
# 4  2022                0       0                NaN     NaN      nan
#
#        Заявка  Позиция заявки Материалы тур. Материалы анг.  ...  \
# 0  2200000578            1890            NaN            NaN  ...
# 1  2200000578            1880            NaN            NaN  ...
# 2  2200000578            1900            NaN            NaN  ...
# 3  2200000578            1910            NaN            NaN  ...
# 4  2200000578            1870            NaN            NaN  ...
#
#   Автор Внутреннего заказа Количество по счету.2 Значок "поставка завершена"  \
# 0                      NaN                   NaN                         NaN
# 1                      NaN                   NaN                         NaN
# 2                      NaN                   NaN                         NaN
# 3                      NaN                   NaN                         NaN
# 4                      NaN                   NaN                         NaN
#
#   Дата контракта Дата вступления в силу контракта  \
# 0            NaN                              NaN
# 1            NaN                              NaN
# 2            NaN                              NaN
# 3            NaN                              NaN
# 4            NaN                              NaN
#
#    Дата окончания действия договора Склад № комиссии         B3-B3POZ  \
# 0                               NaN   NaN        NaN  2200000578_1890
# 1                               NaN   NaN        NaN  2200000578_1880
# 2                               NaN   NaN        NaN  2200000578_1900
# 3                               NaN   NaN        NaN  2200000578_1910
# 4                               NaN   NaN        NaN  2200000578_1870
#
#   имя_поставщика
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 67 columns]

# %%
 # Sözlük oluştur (anahtar: B3-B3POZ, değer: Материал)
b3_to_material_dict = dict(zip(df_me5a_2022_2025["B3-B3POZ"].astype(str), df_me5a_2022_2025["Материал"]))

# %%
# B3-B3POZ'e göre eşleşen Материал'ları getir (yeni bir sütun olarak)
df_calisilan["Материал_yeni"] = df_calisilan["B3-B3POZ"].astype(str).map(b3_to_material_dict)

# %%
# Sadece boş olan Материал hücrelerini, eşleşen değerle doldur
df_calisilan["Материал"] = df_calisilan["Материал"].fillna(df_calisilan["Материал_yeni"])
# Geçici sütunu silelim
df_calisilan.drop(columns=["Материал_yeni"], inplace=True)

# %%
# Sözlükleri oluştur
ru_dict = dict(zip(df_material_list.iloc[:, 0].astype(str), df_material_list.iloc[:, 1]))
tr_dict = dict(zip(df_material_list.iloc[:, 0].astype(str), df_material_list.iloc[:, 2]))

# Eşleştir
df_calisilan["RU Наименование"] = df_calisilan["Материал"].astype(str).map(ru_dict)
df_calisilan["TR Наименование"] = df_calisilan["Материал"].astype(str).map(tr_dict)

# %%
df_calisilan["Материал"].isna().sum()
# Out:
# np.int64(0)

# %%
df_calisilan[["Материал", "TR Наименование","RU Наименование"]]
# Out:
#           Материал                        TR Наименование  \
# 0              nan                                    NaN
# 1              nan                                    NaN
# 2              nan                                    NaN
# 3              nan                                    NaN
# 4              nan                                    NaN
# ...            ...                                    ...
# 701711        7006  WAREHOUSE MECHANIZATION FOR MATERIALS
# 701712        7000           BASIC CONSTRUCTION EQUIPMENT
# 701713        7000           BASIC CONSTRUCTION EQUIPMENT
# 701714  4500415852           BENZIN PETROL OFISI 95 V/MAX
# 701715  4500415855       YAKIT MOTORIN PETROL OFISI V/MAX
#
#                              RU Наименование
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 701711  СКЛАДСКАЯ МЕХАНИЗАЦИЯ ДЛЯ МАТЕРИАЛОВ
# 701712         ОСНОВНАЯ СТРОИТЕЛЬНАЯ ТЕХНИКА
# 701713         ОСНОВНАЯ СТРОИТЕЛЬНАЯ ТЕХНИКА
# 701714          БЕНЗИН PETROL OFISI 95 V/MAX
# 701715  ТОПЛИВО ДИЗЕЛЬНОЕ PETROL OFISI V/MAX
#
# [463022 rows x 3 columns]

# %%
df_calisilan[["Поставщик", "имя_поставщика"]]
# Out:
#          Поставщик                 имя_поставщика
# 0              nan                            NaN
# 1              nan                            NaN
# 2              nan                            NaN
# 3              nan                            NaN
# 4              nan                            NaN
# ...            ...                            ...
# 701711  1000000513  AHMET MESUT İNAN - KON-FI-MAK
# 701712  1000000513  AHMET MESUT İNAN - KON-FI-MAK
# 701713  1000000513  AHMET MESUT İNAN - KON-FI-MAK
# 701714  1000006423              PETROL OFİSİ A.Ş.
# 701715  1000006423              PETROL OFİSİ A.Ş.
#
# [463022 rows x 2 columns]

# %%
df_calisilan["Документ_закупки"] = df_calisilan["Документ_закупки"].replace("", pd.NA)
df_calisilan["Зп_Поз"] = df_calisilan["Зп_Поз"].replace("", pd.NA)
df_calisilan["Зп_Поз"] = df_calisilan["Зп_Поз"].replace(" ", pd.NA)
df_calisilan["Зп_Поз"] = df_calisilan["Зп_Поз"].replace(0, pd.NA)

# %%
sorted_columns = sorted(df_calisilan.columns)
print(sorted_columns)
# Out:
# ['B3-B3POZ', 'RU Наименование', 'TR Наименование', 'Автор Внутреннего заказа', 'БЕ', 'Валюта', 'Валюта ЗП', 'Валюта.1', 'Валюта.2', 'Вид докум. закупки', 'Вид докум. закупки.1', 'ГОД', 'Группа закупок', 'Группа закупок.1', 'Группа материалов', 'Дата вступления в силу контракта', 'Дата доставки, одобренная Поставщиком', 'Дата контракта', 'Дата окончания действия договора', 'Дата поставки', 'Дата проводки', 'Дата создания', 'Дата создания.1', 'Документ_закупки', 'ЕИ заказа на постав.', 'Единица ЗП', 'Единица цены', 'Завод', 'Закуп. организация', 'Заявка', 'Значок "поставка завершена"', 'Зп_Поз', 'Имя 1', 'Инвентарный номер в SAS', 'Индикатор удаления', 'Итого цена нетто', 'Количество ЗП', 'Количество по счету', 'Количество по счету.1', 'Количество по счету.2', 'Количество поставки', 'Краткий текст', 'Материал', 'Материалы анг.', 'Материалы тур.', 'Минимальная цена ЗП', 'Минимальная цена ЗП.1', 'Минимальная цена ЗП.2', 'Название ГрЗакупок', 'Название ГрЗакупок.1', 'Название ЗакупОрг', 'Название группы', 'Название фирмы', 'Недопоставленное количество', 'Обозначение ВидДокум', 'Остаток количества по счету', 'Остаток суммы по счету', 'Позиция заявки', 'Поставщик', 'Склад', 'Создал', 'Создал.1', 'Стоимость брутто', 'Сумма брутто', 'Цена заказа нетто', 'Цена нетто ЗП', 'имя_поставщика', 'неполн.', '№ комиссии']

# %%
df_calisilan.drop(columns=['Материалы тур.', 'Материалы анг.'], inplace=True)

# %%
# Sütunu al
col = df_calisilan.pop('RU Наименование')
col = df_calisilan.pop('TR Наименование')
col = df_calisilan.pop('B3-B3POZ')
# 9. sıraya (yani index=8) ekle
df_calisilan.insert(1, 'B3-B3POZ', col)
df_calisilan.insert(8, 'RU Наименование', col)
df_calisilan.insert(9, 'TR Наименование', col)

# %% [markdown]
# yıllara göre bölmek için aşağıdaki kodu kullan

# %%
df_zmm059_2022_temiz = df_calisilan[df_calisilan["ГОД"] == "2022"]
df_zmm059_2023_temiz = df_calisilan[df_calisilan["ГОД"] == "2023"]
df_zmm059_2024_temiz = df_calisilan[df_calisilan["ГОД"] == "2024"]
df_zmm059_2025_temiz = df_calisilan[df_calisilan["ГОД"] == "2025"]

# %% [markdown]
# excelleri kaydetmek için kullan

# %%
 #XLSX formatında kaydetme
df_calisilan.to_excel("zmm059_2022_2025_temiz.xlsx", index=False, engine="xlsxwriter")
#df_zmm059_2022_temiz.to_excel("zmm059_2022_temiz.xlsx", index=False)
#df_zmm059_2023_temiz.to_excel("zmm059_2023_temiz.xlsx", index=False)
#df_zmm059_2024_temiz.to_excel("zmm059_2024_temiz.xlsx", index=False)
#df_zmm059_2025_temiz.to_excel("zmm059_2025_temiz.xlsx", index=False)

# %% [markdown]
# excelleri indirmek için kullan

# %%
# Dosyayı indir
files.download("zmm059_2022_2025_temiz.xlsx")
#files.download("zmm059_2022_temiz.xlsx")
#files.download("zmm059_2023_temiz.xlsx")
#files.download("zmm059_2024_temiz.xlsx")
#files.download("zmm059_2025_temiz.xlsx")
#files.download("zmm059_2022_2025_temizsutunsuz.csv")
