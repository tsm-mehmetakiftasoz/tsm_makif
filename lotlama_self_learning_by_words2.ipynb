# %% [markdown]
# <a href="https://colab.research.google.com/github/tsm-mehmetakiftasoz/tsm_makif/blob/main/lotlama_self_learning_by_words2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
del me5a

# %%
import pandas as pd

file_path = "/content/me5a.csv"

try:
    me5a = pd.read_csv(file_path, sep=",", encoding="utf-8-sig")
except:
    try:
        me5a = pd.read_csv(file_path, sep=";", encoding="utf-8-sig")
    except:
        me5a = pd.read_csv(file_path, engine="python")

print(me5a.shape)
me5a.head()
# Out:
# (20815, 21)
#       Unnamed: 0   ГОД      Заявка  Позиция заявки Дата заявки      Материал  \
# 0  2200019066_10  2026  2200019066              10   8.04.2026  4.500533e+09
# 1  2200019066_20  2026  2200019066              20   8.04.2026  4.500533e+09
# 2  2200019066_30  2026  2200019066              30   8.04.2026  4.500533e+09
# 3  2200019066_40  2026  2200019066              40   8.04.2026  4.500533e+09
# 4  2200019066_50  2026  2200019066              50   8.04.2026  4.500533e+09
#
#   Индикатор удаления_B3 ЗатребованКолич Единица измерения   Затребовал  ...  \
# 0                YANLIŞ               1                ШТ  Poberezhnik  ...
# 1                YANLIŞ               1                ШТ  Poberezhnik  ...
# 2                YANLIŞ               1                ШТ  Poberezhnik  ...
# 3                YANLIŞ               1                ШТ  Poberezhnik  ...
# 4                YANLIŞ               1                ШТ  Poberezhnik  ...
#
#                                      RU Наименование  \
# 0  КОРОБКА КЛЕММНАЯ ПР 12SAE25AN001 ТУ 343320-001...
# 1  КОРОБКА КЛЕММНАЯ ПР 12SAE25AN002 ТУ 343320-001...
# 2  КОРОБКА КЛЕММНАЯ ПР 12SAC24AN001 ТУ 343320-001...
# 3  КОРОБКА КЛЕММНАЯ ПР 12SAC24AN002 ТУ 343320-001...
# 4  КОРОБКА КЛЕММНАЯ ПР 12SAD21AN001 ТУ 343320-001...
#
#                                      TR Наименование  \
# 0  TERMINAL KUTUSU PR 12SAE25AN001 TU 343320-001-...
# 1  TERMINAL KUTUSU PR 12SAE25AN002 TU 343320-001-...
# 2  TERMINAL KUTUSU PR 12SAC24AN001 TU 343320-001-...
# 3  TERMINAL KUTUSU PR 12SAC24AN002 TU 343320-001-...
# 4  TERMINAL KUTUSU PR 12SAD21AN001 TU 343320-001-...
#
#                                    Дополнительное  \
# 0  По автроскому листу от 28.03.2026 во вложении.
# 1  По автроскому листу от 28.03.2026 во вложении.
# 2  По автроскому листу от 28.03.2026 во вложении.
# 3  По автроскому листу от 28.03.2026 во вложении.
# 4  По автроскому листу от 28.03.2026 во вложении.
#
#                               Краткий текст                Инвентарный номер  \
# 0  КОРОБКА КЛЕММНАЯ ПР 12SAE25AN001 ТУ 3433  AKU.0120.12UBN.0.EM.MB0002(C01)
# 1  КОРОБКА КЛЕММНАЯ ПР 12SAE25AN002 ТУ 3433  AKU.0120.12UBN.0.EM.MB0002(C01)
# 2  КОРОБКА КЛЕММНАЯ ПР 12SAC24AN001 ТУ 3433  AKU.0120.12UBN.0.EM.MB0002(C01)
# 3  КОРОБКА КЛЕММНАЯ ПР 12SAC24AN002 ТУ 3433  AKU.0120.12UBN.0.EM.MB0002(C01)
# 4  КОРОБКА КЛЕММНАЯ ПР 12SAD21AN001 ТУ 3433  AKU.0120.12UBN.0.EM.MB0002(C01)
#
#   Дата_заявки Группа материалов Группа деблокир.  Заказанное к-во  \
# 0   8.04.2026           MZ-4999              3.0                0
# 1   8.04.2026           MZ-4999              3.0                0
# 2   8.04.2026           MZ-4999              3.0                0
# 3   8.04.2026           MZ-4999              3.0                0
# 4   8.04.2026           MZ-4999              3.0                0
#
#   Закуп. Организация
# 0               2993
# 1               2993
# 2               2993
# 3               2993
# 4               2993
#
# [5 rows x 21 columns]

# %%
me5a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20815 entries, 0 to 20814
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             20815 non-null  object
#  1   ГОД                    20815 non-null  int64
#  2   Заявка                 20815 non-null  int64
#  3   Позиция заявки         20815 non-null  int64
#  4   Дата заявки            20815 non-null  object
#  5   Материал               20801 non-null  float64
#  6   Индикатор удаления_B3  20815 non-null  object
#  7   ЗатребованКолич        20815 non-null  object
#  8   Единица измерения      20815 non-null  object
#  9   Затребовал             20815 non-null  object
#  10  Группа закупок         20815 non-null  int64
#  11  RU Наименование        20801 non-null  object
#  12  TR Наименование        20561 non-null  object
#  13  Дополнительное         10342 non-null  object
#  14  Краткий текст          20815 non-null  object
#  15  Инвентарный номер      17787 non-null  object
#  16  Дата_заявки            20815 non-null  object
#  17  Группа материалов      20815 non-null  object
#  18  Группа деблокир.       20813 non-null  float64
#  19  Заказанное к-во        20815 non-null  object
#  20  Закуп. Организация     20815 non-null  int64
# dtypes: float64(2), int64(5), object(14)
# memory usage: 3.3+ MB

# %%
import pandas as pd
import re
from difflib import SequenceMatcher
from collections import Counter

# --------------------------------------------------
# 1. TEXT CLEANING
# --------------------------------------------------

def clean_text_ru(text):
    if pd.isna(text):
        return ""

    text = str(text).lower().strip()

    # Rusça normalizasyon
    text = text.replace("ё", "е")

    # karşılaştırma operatörleri
    text = re.sub(r"[<>]=?", " ", text)

    # sayılar arasındaki nokta: 2.5 -> 2 5
    text = re.sub(r"(\d)\.(\d)", r"\1 \2", text)

    # noktalama ve özel karakterler
    text = re.sub(r"[^\w\s]", " ", text)

    # tek karakterleri kaldır
    text = re.sub(r"\b\w\b", " ", text)

    # fazla boşlukları temizle
    text = re.sub(r"\s+", " ", text)

    return text.strip()


def tokenize(text):
    if not text:
        return []
    return text.split()

# %%
# --------------------------------------------------
# 2. LOTLAMA İÇİN TEMEL HAZIRLIK
# --------------------------------------------------

me5a["Дата заявки"] = pd.to_datetime(me5a["Дата заявки"], errors="coerce")

me5a["Материал"] = me5a["Материал"].apply(
    lambda x: str(int(x)) if pd.notnull(x) else ""
)

me5a["RU Наименование"] = me5a["RU Наименование"].fillna("").astype(str)
me5a["Дополнительное"] = me5a["Дополнительное"].fillna("").astype(str)
me5a["Группа материалов"] = me5a["Группа материалов"].fillna("").astype(str)
me5a["Инвентарный номер"] = me5a["Инвентарный номер"].fillna("").astype(str)

me5a["item_id"] = (
    me5a["Заявка"].astype(str).str.strip() + "_" +
    me5a["Позиция заявки"].astype(str).str.strip()
)

me5a["full_text"] = (
    me5a["RU Наименование"].str.strip() + " | " +
    me5a["Дополнительное"].str.strip() + " | " +
    me5a["Группа материалов"].str.strip()
)

me5a["clean_text"] = me5a["full_text"].apply(clean_text_ru)
me5a["tokens"] = me5a["clean_text"].apply(tokenize)

lot_df = me5a[
    [
        "item_id",
        "ГОД",
        "Заявка",
        "Позиция заявки",
        "Материал",
        "Дата заявки",
        "RU Наименование",
        "Дополнительное",
        "Инвентарный номер",
        "Группа материалов",
        "Закуп. Организация",
        "full_text",
        "clean_text",
        "tokens"
    ]
].copy()

lot_df = lot_df.sort_values(
    by=["Дата заявки", "Заявка", "Позиция заявки"],
    ascending=[True, True, True]
).reset_index(drop=True)

print(lot_df.shape)
lot_df.head()
# Out:
# (20815, 14)
#           item_id   ГОД      Заявка  Позиция заявки    Материал Дата заявки  \
# 0  2200000522_200  2022  2200000522             200  4500079610  2022-02-12
# 1   2200000281_50  2022  2200000281              50  4500093229  2022-03-11
# 2   2200000283_50  2022  2200000283              50  4500146392  2022-04-11
# 3   2200000292_10  2022  2200000292              10  4500081207  2022-04-11
# 4   2200000292_20  2022  2200000292              20  4500059879  2022-04-11
#
#                                      RU Наименование  \
# 0  НАКЛЕЙКА "А" ДЛЯ ИДЕНТИФИКАЦИИ СВЕТИЛЬНИКОВ С ...
# 1  РАСТВОРИТЕЛЬ JOTUN THINNER № 17 ДЛЯ ПОКРЫТИЯ Э...
# 2     ЖГУТ ИЗОЛЯЦИОННЫЙ 20 ММ, ВСПЕНЕННЫЙ ПОЛИЭТИЛЕН
# 3  ПОКРЫТИЕ ДЛЯ ГИДРОИЗОЛЯЦИИ ДВУХКОМПОНЕНТНОЕ ПО...
# 4  ГРУНТОВКА ДВУХКОМПОНЕНТНАЯ ГЛУБОКОГО ПРОНИКНОВ...
#
#                                       Дополнительное  \
# 0
# 1  Requester Igor Mamontov/00ukt.0.ar.lc0002/ЛКМ/...
# 2
# 3
# 4
#
#                  Инвентарный номер Группа материалов  Закуп. Организация  \
# 0  AKU.1480.90VCB.0.EW.TB0001(C01)           MZ-8002                2993
# 1  AKU.0120.00UKT.0.AR.LC0002(C02)           MZ-2032                2991
# 2  AKU.1227.90VDA.0.KZ.LB0010(C01)           MZ-2033                2993
# 3      AKU.2004.0.0.CS.DZ0003(C02)           MZ-2068                2991
# 4      AKU.2004.0.0.CS.DZ0003(C02)           MZ-2032                2991
#
#                                            full_text  \
# 0  НАКЛЕЙКА "А" ДЛЯ ИДЕНТИФИКАЦИИ СВЕТИЛЬНИКОВ С ...
# 1  РАСТВОРИТЕЛЬ JOTUN THINNER № 17 ДЛЯ ПОКРЫТИЯ Э...
# 2  ЖГУТ ИЗОЛЯЦИОННЫЙ 20 ММ, ВСПЕНЕННЫЙ ПОЛИЭТИЛЕН...
# 3  ПОКРЫТИЕ ДЛЯ ГИДРОИЗОЛЯЦИИ ДВУХКОМПОНЕНТНОЕ ПО...
# 4  ГРУНТОВКА ДВУХКОМПОНЕНТНАЯ ГЛУБОКОГО ПРОНИКНОВ...
#
#                                           clean_text  \
# 0  наклейка для идентификации светильников аварий...
# 1  растворитель jotun thinner 17 для покрытия эпо...
# 2  жгут изоляционный 20 мм вспененный полиэтилен ...
# 3  покрытие для гидроизоляции двухкомпонентное по...
# 4  грунтовка двухкомпонентная глубокого проникнов...
#
#                                               tokens
# 0  [наклейка, для, идентификации, светильников, а...
# 1  [растворитель, jotun, thinner, 17, для, покрыт...
# 2  [жгут, изоляционный, 20, мм, вспененный, полиэ...
# 3  [покрытие, для, гидроизоляции, двухкомпонентно...
# 4  [грунтовка, двухкомпонентная, глубокого, прони...

# %%
me5a.columns
# Out:
# Index(['Unnamed: 0', 'ГОД', 'Заявка', 'Позиция заявки', 'Дата заявки',
#        'Материал', 'Индикатор удаления_B3', 'ЗатребованКолич',
#        'Единица измерения', 'Затребовал', 'Группа закупок', 'RU Наименование',
#        'TR Наименование', 'Дополнительное', 'Краткий текст',
#        'Инвентарный номер', 'Дата_заявки', 'Группа материалов',
#        'Группа деблокир.', 'Заказанное к-во', 'Закуп. Организация', 'item_id',
#        'full_text', 'clean_text', 'tokens'],
#       dtype='object')

# %%
me5a["RU Наименование"].sample(n=5)
# Out:
# 15298                ДИСК ПИЛЬНЫЙ ПО ДЕРЕВУ 180X20 ММ Z=24
# 14631    НАКОНЕЧНИК Ф."КВТ" МЕДНЫЙ ЛУЖЁННЫЙ ПОД ОПРЕССО...
# 2563                                 ЛЮК Т(С250) TS EN 124
# 12466     ИНСТРУМЕНТ РУЧНОЙ: КЛЮЧ ДЛЯ ГИБКИ АРМАТУРЫ 22 ММ
# 9741     ДЕРЖАТЕЛЬ ТРУБЫ МЕТАЛЛИЧЕСКИЙ (НА КИРПИЧ) D150...
# Name: RU Наименование, dtype: object

# %%
me5a[me5a["RU Наименование"].str.contains("oglaend.", na=False)].sample(n=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2719/2226748834.py in <cell line: 0>()
# ----> 1 me5a[me5a["RU Наименование"].str.contains("oglaend.", na=False)].sample(n=5)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6116             weights = sample.preprocess_weights(self, weights, axis)
#    6117
# -> 6118         sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6119         result = self.take(sampled_indices, axis=axis)
#    6120
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/sample.py in sample(obj_len, size, replace, weights, random_state)
#     150             raise ValueError("Invalid weights: weights sum to zero")
#     151
# --> 152     return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153         np.intp, copy=False
#     154     )
#
# numpy/random/mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
# --------------------------------------------------
# 3. FIXED LOT DICTIONARY
# --------------------------------------------------

fixed_lots = {
    "LOT_HILTI": {
        "type": "fixed",
        "keywords": ["hilti","HILTI"],
        "update_allowed": False
    },
    "LOT_OGLAEND": {
        "type": "fixed",
        "keywords": ["oglaend","OGLAEND"],
        "update_allowed": False
    },
    "LOT_SIKA": {
        "type": "fixed",
        "keywords": ["sika","SIKA","SİKA"],
        "update_allowed": False
    },
    "LOT_AKU_DOT": {
        "type": "fixed",
        "keywords": ["AKU."],
        "update_allowed": False
    },
    "LOT_BETON": {
        "type": "fixed",
        "keywords": ["бетон","БЕТОН "],
        "update_allowed": False
    },
    "LOT_КРАСКА": {
        "type": "fixed",
        "keywords": ["краск","КРАСК","JOTUN","jotun",],
        "update_allowed": False
    },
    "LOT_БОЛТ": {
        "type": "fixed",
        "keywords": ["болт","гайка","шайба",],
        "update_allowed": False
    },
    "LOT_БОЛТ": {
        "type": "fixed",
        "keywords": ["болт","гайка","шайба",],
        "update_allowed": False
    }

}

# %%
# --------------------------------------------------
# 4. "aku." KONTROLÜ
# --------------------------------------------------

def matches_aku_dot_rule(row):
    raw_fields = [
        str(row.get("RU Наименование", "")).lower(),
        str(row.get("Дополнительное", "")).lower(),
        str(row.get("Инвентарный номер", "")).lower(),
        str(row.get("full_text", "")).lower()
    ]

    for field in raw_fields:
        if "aku." in field:
            return True

    return False

# %%
# --------------------------------------------------
# 5. FIXED LOT KONTROLÜ
# --------------------------------------------------

def check_fixed_lot(row, fixed_lots):
    # 1) Özel "aku." kuralı
    if matches_aku_dot_rule(row):
        return "LOT_AKU_DOT"

    # 2) Keyword bazlı fixed lotlar
    text = str(row.get("RU Наименование", "")).lower()

    for lot_id, lot_data in fixed_lots.items():
        if lot_id == "LOT_AKU_DOT":
            continue

        for kw in lot_data["keywords"]:
            if kw in text:
                return lot_id

    return None

# %%
# --------------------------------------------------
# 6. SKOR FONKSİYONLARI
# --------------------------------------------------

def text_similarity(a, b):
    if not a or not b:
        return 0.0
    return SequenceMatcher(None, a, b).ratio()


def keyword_overlap_score(item_tokens, lot_keywords, max_score=30):
    if not item_tokens or not lot_keywords:
        return 0.0

    item_set = set(item_tokens)
    kw_set = set(lot_keywords)

    overlap = len(item_set & kw_set)
    ratio = overlap / max(len(kw_set), 1)

    return round(min(max_score, ratio * max_score), 2)


def representative_score(item_text, rep_texts, max_score=60):
    if not item_text or not rep_texts:
        return 0.0

    sims = [text_similarity(item_text, rep) for rep in rep_texts]

    max_sim = max(sims)
    avg_sim = sum(sims) / len(sims)

    combined = 0.7 * max_sim + 0.3 * avg_sim
    return round(combined * max_score, 2)


def group_bonus_score(row, lot_data, max_score=10):
    row_org = str(row.get("Закуп. организация", "")).strip()
    lot_org = str(lot_data.get("org", "")).strip()

    if row_org and lot_org and row_org == lot_org:
        return max_score

    return 0.0


def score_learned_lot(row, lot_data):
    item_text = row["clean_text"]
    item_tokens = row["tokens"]

    kw_score = keyword_overlap_score(item_tokens, lot_data["keywords"], max_score=30)
    rep_score = representative_score(item_text, lot_data["representative_texts"], max_score=60)
    grp_score = group_bonus_score(row, lot_data, max_score=10)

    total_score = kw_score + rep_score + grp_score
    return round(total_score, 2)

# %%
# --------------------------------------------------
# 7. YENİ LEARNED LOT OLUŞTURMA
# --------------------------------------------------

def create_new_learned_lot(row, lot_counter):
    lot_id = f"LOT_{lot_counter:04d}"

    text = row["clean_text"]
    tokens = row["tokens"]

    lot_data = {
        "type": "learned",
        "keywords": list(dict.fromkeys(tokens[:10])),
        "anchor_text": text,
        "representative_texts": [text] if text else [],
        "update_allowed": True,
        "org": row.get("Закуп. организация", "")
    }

    return lot_id, lot_data

# %%
# --------------------------------------------------
# 8. LEARNED LOT GÜNCELLEME
# --------------------------------------------------

def should_learn(best_score, margin, lot_data):
    if not lot_data.get("update_allowed", False):
        return False

    if best_score >= 85 and margin >= 10:
        return True

    return False


def should_add_representative(new_text, rep_texts, similarity_threshold=0.92):
    if not new_text:
        return False

    if not rep_texts:
        return True

    sims = [text_similarity(new_text, rep) for rep in rep_texts]
    if max(sims) >= similarity_threshold:
        return False

    return True


def update_learned_lot(row, lot_data, max_reps=5, max_keywords=10):
    new_text = row["clean_text"]
    new_tokens = row["tokens"]

    # representative_texts güncelle
    if should_add_representative(new_text, lot_data["representative_texts"]):
        lot_data["representative_texts"].append(new_text)

        if len(lot_data["representative_texts"]) > max_reps:
            lot_data["representative_texts"] = lot_data["representative_texts"][:max_reps]

    # keywords güncelle
    merged = lot_data["keywords"] + new_tokens
    counts = Counter(merged)
    top_keywords = [k for k, v in counts.most_common(max_keywords)]
    lot_data["keywords"] = top_keywords

    return lot_data

# %%
# --------------------------------------------------
# 9. TEK KAYIT İÇİN LOT ATAMA
# --------------------------------------------------

def assign_lot_for_row(row, lots_dict, lot_counter_start):
    # 1) Fixed lot kontrolü
    fixed_lot_id = check_fixed_lot(row, fixed_lots)
    if fixed_lot_id is not None:
        return {
            "assigned_lot": fixed_lot_id,
            "decision_type": "fixed_rule",
            "best_score": 100.0,
            "second_score": 0.0,
            "margin": 100.0,
            "lot_counter": lot_counter_start
        }

    # 2) Learned lotlar arasından skorla
    learned_scores = []

    for lot_id, lot_data in lots_dict.items():
        if lot_data["type"] != "learned":
            continue

        score = score_learned_lot(row, lot_data)
        learned_scores.append((lot_id, score))

    # 3) Hiç learned lot yoksa yeni lot aç
    if len(learned_scores) == 0:
        new_lot_id, new_lot_data = create_new_learned_lot(row, lot_counter_start)
        lots_dict[new_lot_id] = new_lot_data

        return {
            "assigned_lot": new_lot_id,
            "decision_type": "new_lot_created",
            "best_score": 0.0,
            "second_score": 0.0,
            "margin": 0.0,
            "lot_counter": lot_counter_start + 1
        }

    learned_scores = sorted(learned_scores, key=lambda x: x[1], reverse=True)

    best_lot, best_score = learned_scores[0]
    second_score = learned_scores[1][1] if len(learned_scores) > 1 else 0.0
    margin = round(best_score - second_score, 2)

    # 4) Karar
    if best_score >= 75:
        # Learned lota ata
        if should_learn(best_score, margin, lots_dict[best_lot]):
            lots_dict[best_lot] = update_learned_lot(row, lots_dict[best_lot])

        return {
            "assigned_lot": best_lot,
            "decision_type": "assigned_existing_learned",
            "best_score": best_score,
            "second_score": second_score,
            "margin": margin,
            "lot_counter": lot_counter_start
        }

    elif 60 <= best_score < 75:
        # Şimdilik review yerine yine lot ata ama flag koy
        return {
            "assigned_lot": best_lot,
            "decision_type": "review_needed",
            "best_score": best_score,
            "second_score": second_score,
            "margin": margin,
            "lot_counter": lot_counter_start
        }

    else:
        # Yeni learned lot aç
        new_lot_id, new_lot_data = create_new_learned_lot(row, lot_counter_start)
        lots_dict[new_lot_id] = new_lot_data

        return {
            "assigned_lot": new_lot_id,
            "decision_type": "new_lot_created",
            "best_score": best_score,
            "second_score": second_score,
            "margin": margin,
            "lot_counter": lot_counter_start + 1
        }

# %%
# --------------------------------------------------
# 10. TÜM DATAFRAME İÇİN LOTLAMA
# --------------------------------------------------

def process_me5a_lots(lot_df, fixed_lots):
    lots_dict = {}

    # fixed lotları başlangıçta dictionary'ye koy
    for lot_id, lot_data in fixed_lots.items():
        lots_dict[lot_id] = lot_data.copy()

    results = []
    lot_counter = 1

    for idx, row in lot_df.iterrows():
        result = assign_lot_for_row(row, lots_dict, lot_counter)
        lot_counter = result["lot_counter"]

        results.append({
            "item_id": row["item_id"],
            "Заявка": row["Заявка"],
            "Позиция заявки": row["Позиция заявки"],
            "Дата заявки": row["Дата заявки"],
            "RU Наименование": row["RU Наименование"],
            "Дополнительное": row["Дополнительное"],
            "Инвентарный номер": row["Инвентарный номер"],
            "clean_text": row["clean_text"],
            "assigned_lot": result["assigned_lot"],
            "decision_type": result["decision_type"],
            "best_score": result["best_score"],
            "second_score": result["second_score"],
            "margin": result["margin"]
        })

    result_df = pd.DataFrame(results)
    return result_df, lots_dict

# %%
def process_me5a_lots(lot_df, fixed_lots):
    lots_dict = {}

    for lot_id, lot_data in fixed_lots.items():
        lots_dict[lot_id] = lot_data.copy()

    results = []
    lot_counter = 1
    total_rows = len(lot_df)

    for idx, row in lot_df.iterrows():
        if idx % 5000 == 0:
            print(f"İşlenen satır: {idx} / {total_rows}")

        result = assign_lot_for_row(row, lots_dict, lot_counter)
        lot_counter = result["lot_counter"]

        results.append({
            "item_id": row["item_id"],
            "Заявка": row["Заявка"],
            "Позиция заявки": row["Позиция заявки"],
            "Дата заявки": row["Дата заявки"],
            "RU Наименование": row["RU Наименование"],
            "Дополнительное": row["Дополнительное"],
            "Инвентарный номер": row["Инвентарный номер"],
            "clean_text": row["clean_text"],
            "assigned_lot": result["assigned_lot"],
            "decision_type": result["decision_type"],
            "best_score": result["best_score"],
            "second_score": result["second_score"],
            "margin": result["margin"]
        })

    result_df = pd.DataFrame(results)
    return result_df, lots_dict

# %%
sample_df = lot_df.head(20000).copy()

result_df, final_lots_dict = process_me5a_lots(sample_df, fixed_lots)

print(result_df.shape)
result_df.head(20)
# Out:
# İşlenen satır: 0 / 20000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2719/1768085314.py in <cell line: 0>()
#       1 sample_df = lot_df.head(20000).copy()
#       2
# ----> 3 result_df, final_lots_dict = process_me5a_lots(sample_df, fixed_lots)
#       4
#       5 print(result_df.shape)
#
# /tmp/ipykernel_2719/1288608022.py in process_me5a_lots(lot_df, fixed_lots)
#      13             print(f"İşlenen satır: {idx} / {total_rows}")
#      14
# ---> 15         result = assign_lot_for_row(row, lots_dict, lot_counter)
#      16         lot_counter = result["lot_counter"]
#      17
#
# /tmp/ipykernel_2719/4286288543.py in assign_lot_for_row(row, lots_dict, lot_counter_start)
#      23             continue
#      24
# ---> 25         score = score_learned_lot(row, lot_data)
#      26         learned_scores.append((lot_id, score))
#      27
#
# /tmp/ipykernel_2719/1991555342.py in score_learned_lot(row, lot_data)
#      50
#      51     kw_score = keyword_overlap_score(item_tokens, lot_data["keywords"], max_score=30)
# ---> 52     rep_score = representative_score(item_text, lot_data["representative_texts"], max_score=60)
#      53     grp_score = group_bonus_score(row, lot_data, max_score=10)
#      54
#
# /tmp/ipykernel_2719/1991555342.py in representative_score(item_text, rep_texts, max_score)
#      26         return 0.0
#      27
# ---> 28     sims = [text_similarity(item_text, rep) for rep in rep_texts]
#      29
#      30     max_sim = max(sims)
#
# /tmp/ipykernel_2719/1991555342.py in text_similarity(a, b)
#       6     if not a or not b:
#       7         return 0.0
# ----> 8     return SequenceMatcher(None, a, b).ratio()
#       9
#      10
#
# /usr/lib/python3.12/difflib.py in ratio(self)
#     617         """
#     618
# --> 619         matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     620         return _calculate_ratio(matches, len(self.a) + len(self.b))
#     621
#
# /usr/lib/python3.12/difflib.py in get_matching_blocks(self)
#     452         while queue:
#     453             alo, ahi, blo, bhi = queue.pop()
# --> 454             i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#     455             # a[alo:i] vs b[blo:j] unknown
#     456             # a[i:i+k] same as b[j:j+k]
#
# /usr/lib/python3.12/difflib.py in find_longest_match(self, alo, ahi, blo, bhi)
#     372         j2len = {}
#     373         nothing = []
# --> 374         for i in range(alo, ahi):
#     375             # look at all instances of a[i] in b; note that because
#     376             # b2j has no junk keys, the loop is skipped if a[i] is junk
#
# KeyboardInterrupt:

# %%
result_df, final_lots_dict = process_me5a_lots(lot_df, fixed_lots)

print(result_df.shape)
result_df.head(20)
# Out:
# İşlenen satır: 0 / 20815
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2719/1937938553.py in <cell line: 0>()
# ----> 1 result_df, final_lots_dict = process_me5a_lots(lot_df, fixed_lots)
#       2
#       3 print(result_df.shape)
#       4 result_df.head(20)
#
# /tmp/ipykernel_2719/1288608022.py in process_me5a_lots(lot_df, fixed_lots)
#      13             print(f"İşlenen satır: {idx} / {total_rows}")
#      14
# ---> 15         result = assign_lot_for_row(row, lots_dict, lot_counter)
#      16         lot_counter = result["lot_counter"]
#      17
#
# /tmp/ipykernel_2719/4286288543.py in assign_lot_for_row(row, lots_dict, lot_counter_start)
#      23             continue
#      24
# ---> 25         score = score_learned_lot(row, lot_data)
#      26         learned_scores.append((lot_id, score))
#      27
#
# /tmp/ipykernel_2719/1991555342.py in score_learned_lot(row, lot_data)
#      50
#      51     kw_score = keyword_overlap_score(item_tokens, lot_data["keywords"], max_score=30)
# ---> 52     rep_score = representative_score(item_text, lot_data["representative_texts"], max_score=60)
#      53     grp_score = group_bonus_score(row, lot_data, max_score=10)
#      54
#
# /tmp/ipykernel_2719/1991555342.py in representative_score(item_text, rep_texts, max_score)
#      26         return 0.0
#      27
# ---> 28     sims = [text_similarity(item_text, rep) for rep in rep_texts]
#      29
#      30     max_sim = max(sims)
#
# /tmp/ipykernel_2719/1991555342.py in text_similarity(a, b)
#       6     if not a or not b:
#       7         return 0.0
# ----> 8     return SequenceMatcher(None, a, b).ratio()
#       9
#      10
#
# /usr/lib/python3.12/difflib.py in ratio(self)
#     617         """
#     618
# --> 619         matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     620         return _calculate_ratio(matches, len(self.a) + len(self.b))
#     621
#
# /usr/lib/python3.12/difflib.py in get_matching_blocks(self)
#     452         while queue:
#     453             alo, ahi, blo, bhi = queue.pop()
# --> 454             i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#     455             # a[alo:i] vs b[blo:j] unknown
#     456             # a[i:i+k] same as b[j:j+k]
#
# /usr/lib/python3.12/difflib.py in find_longest_match(self, alo, ahi, blo, bhi)
#     377             j2lenget = j2len.get
#     378             newj2len = {}
# --> 379             for j in b2j.get(a[i], nothing):
#     380                 # a[i] matches b[j]
#     381                 if j < blo:
#
# KeyboardInterrupt:

# %%
result_df["decision_type"].value_counts()
# Out:
# decision_type
# fixed_rule                   19085
# assigned_existing_learned      440
# review_needed                  238
# new_lot_created                237
# Name: count, dtype: int64

# %%
result_df["assigned_lot"].value_counts().head(20)
# Out:
# assigned_lot
# LOT_AKU_DOT    18919
# LOT_0099         108
# LOT_BETON        106
# LOT_0191          83
# LOT_HILTI         60
# LOT_0021          49
# LOT_0214          37
# LOT_0028          35
# LOT_0002          28
# LOT_0236          25
# LOT_0022          23
# LOT_0221          17
# LOT_0036          15
# LOT_0220          15
# LOT_0033          13
# LOT_0211          12
# LOT_0068          10
# LOT_0190          10
# LOT_0074           9
# LOT_0070           9
# Name: count, dtype: int64

# %%
result_df[["RU Наименование","assigned_lot","best_score"]].sample(n=5)
# Out:
#                                          RU Наименование assigned_lot  \
# 16850  НУТРОМЕР МИКРОСКОПИЧЕСКИЙ  НМ-5-30 ЦЕНА ДЕЛЕНИ...     LOT_0180
# 16054                   10UJA.KAA.TM.TB0102-22/27.М194-1  LOT_AKU_DOT
# 8122   КРЫШКА SPB CO-CT-600-3000 HDG C4 АРТ.121581 Ф....  LOT_AKU_DOT
# 9222                   AKU.0120.00USY.0.KM.LC0006.1CRB-6  LOT_AKU_DOT
# 10279                 AKU.0120.00USY.0.KM.LC0019.CRB2/31  LOT_AKU_DOT
#
#        best_score
# 16850        59.5
# 16054       100.0
# 8122        100.0
# 9222        100.0
# 10279       100.0

# %%
result_df.to_excel("/content/me5a_lot_result.xlsx", index=False)
