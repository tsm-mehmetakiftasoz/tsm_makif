# %% [markdown]
# <a href="https://colab.research.google.com/github/tsm-mehmetakiftasoz/tsm_makif/blob/main/%D0%B3%D0%BE%D1%82%D0%BE%D0%B2%D0%BE_ZMB51_%D0%A1%D0%BB%D0%B8%D1%8F%D0%BD%D0%B8%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ZMB51 raporlarını birleştirmek için oluşturuldu. ZMB51 Raporları SAPden çekildikten sonra aşağıdaki gibi kaydedilmelidir. 2022-2024(DAHİL) raporlar
# T:\PD ICTSM\MAKIF\Reporting Division\Aудит SAP\ДАННЫЕ\Colab için CSV\ZMB51
# adresinde mevcut sadece 2025 yeniden çekilip eklenmeli ve .csv formatında kaydedilmeli . sonra run all 'a tıkladığınızda program çalışacak ve birleştirilmiş bir excel olarak çıktı verecek.
# makife not 2025i de 2 ye bölebiliriz. kodu ona göre düzenlemek gerekecek

# %%
# !pip install pandas
# !pip install xlsxwriter
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting xlsxwriter
#   Downloading xlsxwriter-3.2.5-py3-none-any.whl.metadata (2.7 kB)
# Downloading xlsxwriter-3.2.5-py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.3/172.3 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.2.5

# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
df_zmb51_2022 = pd.read_csv('/content/zmb51_2022.csv', sep=None, engine='python')
df_zmb51_2023 = pd.read_csv('/content/zmb51_2023.csv', sep=None, engine='python')
df_zmb51_2024_1 = pd.read_csv('/content/zmb51_2024_1.csv', sep=None, engine='python')
df_zmb51_2024_2 = pd.read_csv('/content/zmb51_2024_2.csv', sep=None, engine='python')
df_zmb51_2024_3 = pd.read_csv('/content/zmb51_2024_3.csv', sep=None, engine='python')
df_zmb51_2024_4 = pd.read_csv('/content/zmb51_2024_4.csv', sep=None, engine='python')
df_zmb51_2024_5 = pd.read_csv('/content/zmb51_2024_5.csv', sep=None, engine='python')
df_zmb51_2024_6 = pd.read_csv('/content/zmb51_2024_6.csv', sep=None, engine='python')
df_zmb51_2024_7 = pd.read_csv('/content/zmb51_2024_7.csv', sep=None, engine='python')
df_zmb51_2025 = pd.read_csv('/content/zmb51_2025.csv', sep=None, engine='python')
# sep=None will automatically detect the delimiter
# engine='python' is slower but more robust for complex cases

# %%
#ilk sutuna yıl yazdırma
df_zmb51_2022["ГОД"] = "2022"
cols = ["ГОД"] + [col for col in df_zmb51_2022.columns if col != "ГОД"]
df_zmb51_2022 = df_zmb51_2022[cols]
#
df_zmb51_2023["ГОД"] = "2023"
cols = ["ГОД"] + [col for col in df_zmb51_2023.columns if col != "ГОД"]
df_zmb51_2023 = df_zmb51_2023[cols]
#
df_zmb51_2025["ГОД"] = "2025"
cols = ["ГОД"] + [col for col in df_zmb51_2025.columns if col != "ГОД"]
df_zmb51_2025 = df_zmb51_2025[cols]
#
df_zmb51_2024_1["ГОД"] = "2024"
cols = ["ГОД"] + [col for col in df_zmb51_2024_1.columns if col != "ГОД"]
df_zmb51_2024_1 = df_zmb51_2024_1[cols]
#
df_zmb51_2024_2["ГОД"] = "2024"
cols = ["ГОД"] + [col for col in df_zmb51_2024_2.columns if col != "ГОД"]
df_zmb51_2024_2 = df_zmb51_2024_2[cols]
#
df_zmb51_2024_3["ГОД"] = "2024"
cols = ["ГОД"] + [col for col in df_zmb51_2024_3.columns if col != "ГОД"]
df_zmb51_2024_3 = df_zmb51_2024_3[cols]
#
df_zmb51_2024_4["ГОД"] = "2024"
cols = ["ГОД"] + [col for col in df_zmb51_2024_4.columns if col != "ГОД"]
df_zmb51_2024_4 = df_zmb51_2024_4[cols]
#
df_zmb51_2024_5["ГОД"] = "2024"
cols = ["ГОД"] + [col for col in df_zmb51_2024_5.columns if col != "ГОД"]
df_zmb51_2024_5 = df_zmb51_2024_5[cols]
#
df_zmb51_2024_6["ГОД"] = "2024"
cols = ["ГОД"] + [col for col in df_zmb51_2024_6.columns if col != "ГОД"]
df_zmb51_2024_6 = df_zmb51_2024_6[cols]
#
df_zmb51_2024_7["ГОД"] = "2024"
cols = ["ГОД"] + [col for col in df_zmb51_2024_7.columns if col != "ГОД"]
df_zmb51_2024_7 = df_zmb51_2024_7[cols]

# %%
df_listesi = [df_zmb51_2022,df_zmb51_2023,df_zmb51_2024_1,df_zmb51_2024_2,df_zmb51_2024_3,df_zmb51_2024_4,df_zmb51_2024_5,df_zmb51_2024_6,df_zmb51_2024_7,df_zmb51_2025]

# %%
birlesik_df = pd.concat(df_listesi, ignore_index=True)

# %%
birlesik_df.head()
# Out:
#     ГОД  ﻿Вид движения Склад  Дата ввода Время ввода Дата документа  \
# 0  2022            101   NaN  23.02.2023    17:13:34     31.12.2022
# 1  2022            101   NaN  24.02.2023    11:24:08     31.07.2022
# 2  2022            101   NaN  24.01.2023    11:54:05     18.09.2022
# 3  2022            101   NaN  19.01.2023    14:10:24      1.12.2022
# 4  2022            101   NaN  25.11.2022    17:03:34     31.07.2022
#
#   Дата проводки  Внутренний заказ  Заказ на поставку  Позиция  ...  \
# 0     1.12.2022               NaN         7200001002       10  ...
# 1     1.12.2022               NaN         7200001003       10  ...
# 2     1.11.2022               NaN         7200000961      100  ...
# 3     1.12.2022               NaN         7200000952       10  ...
# 4    31.07.2022               NaN         7200000875       10  ...
#
#    Имя пользователя    БЕ Базовая ЕИ  ГодДокумМатериала Валюта Завод Имя 1  \
# 0        MBURMAKOVA  2990        NaN               2022    TRY  29A2   TSM
# 1        MBURMAKOVA  2990        NaN               2022    TRY  29A2   TSM
# 2        ZBONDAREVA  2990        NaN               2022    TRY  29A2   TSM
# 3          MVOLKOVA  2990        NaN               2022    TRY  29A2   TSM
# 4          MVOLKOVA  2990        NaN               2022    TRY  29A2   TSM
#
#   Основное средство ЕИ цены заказа ЕИ заказа на постав.
# 0               NaN             ЕР                   ЕР
# 1               NaN             ЕР                   ЕР
# 2               NaN             ЕР                   ЕР
# 3               NaN             ЕР                   ЕР
# 4               NaN             ЕР                   ЕР
#
# [5 rows x 35 columns]

# %%
birlesik_df.sample(10, random_state=24)
# Out:
#          ГОД  ﻿Вид движения Склад  Дата ввода Время ввода Дата документа  \
# 291323  2025            101  4226  20.05.2025    17:45:15     10.02.2025
# 241028  2024            102   KKS  11.12.2024    11:12:37     11.12.2024
# 113117  2024            101  0002  27.05.2024    12:55:43     28.02.2023
# 46380   2023            101  0002  17.11.2023    18:15:54     30.06.2023
# 290002  2025            101  0002   8.05.2025    15:40:05     21.04.2025
# 23352   2023            101  Z003  14.11.2023    19:29:14     23.08.2023
# 139201  2024            101  4105  17.07.2024    20:27:31     20.02.2024
# 193004  2024            101  0002  22.10.2024    12:04:54     25.09.2023
# 19751   2022            101  0002   7.04.2023    17:24:28     21.10.2022
# 81945   2024            101  0002  29.03.2024    10:50:46     11.11.2023
#
#        Дата проводки  Внутренний заказ  Заказ на поставку  Позиция  ...  \
# 291323    20.05.2025      9.900004e+09         3100013128      140  ...
# 241028    11.12.2024      2.200013e+09         3100011183     5540  ...
# 113117    27.05.2024               NaN         3100006931     2480  ...
# 46380     17.11.2023      2.200002e+09         3100004876     4510  ...
# 290002     8.05.2025      9.900000e+09         3100008349     1510  ...
# 23352     19.10.2023      2.200002e+09         3100002443       30  ...
# 139201    17.07.2024      9.900001e+09         3100008347     5190  ...
# 193004    22.10.2024      9.900001e+09         3100009658     3980  ...
# 19751      1.12.2022      2.200002e+09         3100001481    11480  ...
# 81945      1.02.2024               NaN         3100006719       80  ...
#
#         Имя пользователя    БЕ Базовая ЕИ  ГодДокумМатериала Валюта Завод  \
# 291323           AMOREVA  2990         ШТ               2025    TRY  29A2
# 241028          OLUGOVIK  2990         ШТ               2024    TRY  29A2
# 113117      ZABDUKARIMOV  2990         ШТ               2024    TRY  29A2
# 46380              EKILO  2990         ШТ               2023    TRY  29A2
# 290002            STOKER  2990         ШТ               2025    TRY  29A2
# 23352        SAPYSHATOVA  2990         ШТ               2023    TRY  29A2
# 139201           AMOREVA  2990         ШТ               2024    TRY  29A2
# 193004       LRAKHMANOVA  2990         ШТ               2024    TRY  29A2
# 19751       ZABDUKARIMOV  2990         КГ               2022    TRY  29A2
# 81945             NBULUT  2990         КГ               2024    TRY  29A2
#
#        Имя 1 Основное средство ЕИ цены заказа ЕИ заказа на постав.
# 291323   TSM               NaN             ШТ                   ШТ
# 241028   TSM               NaN             ШТ                   ШТ
# 113117   TSM               NaN             ШТ                   ШТ
# 46380    TSM               NaN             ШТ                   ШТ
# 290002   TSM               NaN             ШТ                   ШТ
# 23352    TSM               NaN             ШТ                   ШТ
# 139201   TSM               NaN             ШТ                   ШТ
# 193004   TSM               NaN             ШТ                   ШТ
# 19751    TSM               NaN             КГ                   КГ
# 81945    TSM               NaN             КГ                   КГ
#
# [10 rows x 35 columns]

# %%
len(birlesik_df)
# Out:
# 304511

# %%
birlesik_df.to_excel("zmb51_2022_2025_temiz.xlsx", index=False, engine="xlsxwriter")

# %%
files.download("zmb51_2022_2025_temiz.xlsx")

# %% [markdown]
# Eğer csv kaydetmek istersen aşağıdaki kodları yorumdan çıkart
# Если вы хотите сохранить как CSV, закомментируйте коды ниже.

# %%
#birlesik_df.to_csv("zmb51_2022_2025_temiz.csv", index=False)

# %%
#files.download("zmb51_2022_2025_temiz.csv")
