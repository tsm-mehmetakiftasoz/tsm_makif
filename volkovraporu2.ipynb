# %% [markdown]
# <a href="https://colab.research.google.com/github/tsm-mehmetakiftasoz/tsm_makif/blob/main/volkovraporu2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
# !pip install pandas
import pandas as pd
import glob
# !pip install xlsxwriter
import csv
import numpy as np
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting xlsxwriter
#   Downloading xlsxwriter-3.2.5-py3-none-any.whl.metadata (2.7 kB)
# Downloading xlsxwriter-3.2.5-py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.3/172.3 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.2.5

# %%
MB51_17122024 = pd.read_excel("/content/MB51_17122024.XLSX", engine='openpyxl')
MB51_23092024 = pd.read_excel("/content/MB51_23092024.XLSX", engine='openpyxl')
MB51_26032025 = pd.read_excel("/content/MB51_26032025.XLSX", engine='openpyxl')
MB51_26112024 = pd.read_excel("/content/MB51_26112024.XLSX", engine='openpyxl')
MB51_27062025 = pd.read_excel("/content/MB51_27062025.XLSX", engine='openpyxl')

# %%
MB51_28012025 = pd.read_excel("/content/MB51_28012025.XLSX", engine='openpyxl')
MB51_28022025 = pd.read_excel("/content/MB51_28022025.XLSX", engine='openpyxl')
MB51_30042025 = pd.read_excel("/content/MB51_30042025.XLSX", engine='openpyxl')
MB51_30052025 = pd.read_excel("/content/MB51_30052025.XLSX", engine='openpyxl')
MB51_30102024 = pd.read_excel("/content/MB51_30102024.XLSX", engine='openpyxl')
MB51_31072025 = pd.read_excel("/content/MB51_31072025.XLSX", engine='openpyxl')

# %%
zmb51 = pd.read_excel("/content/zmb51_2022_2025_temiz (1).xlsx", engine='openpyxl')

# %%
me5a = pd.read_excel("/content/me5a_2022_2025 (1).xlsx", engine='openpyxl')

# %%
me2n = pd.read_excel("/content/me2n_2022_2025_temiz.xlsx", engine='openpyxl')

# %%
# Her df için Dosya_Adi sütunu ekle ve ilk sütun yap
MB51_17122024["Dosya_Adi"] = "MB51_17122024"
cols = ["Dosya_Adi"] + [col for col in MB51_17122024.columns if col != "Dosya_Adi"]
MB51_17122024 = MB51_17122024[cols]

MB51_23092024["Dosya_Adi"] = "MB51_23092024"
cols = ["Dosya_Adi"] + [col for col in MB51_23092024.columns if col != "Dosya_Adi"]
MB51_23092024 = MB51_23092024[cols]

MB51_26032025["Dosya_Adi"] = "MB51_26032025"
cols = ["Dosya_Adi"] + [col for col in MB51_26032025.columns if col != "Dosya_Adi"]
MB51_26032025 = MB51_26032025[cols]

MB51_26112024["Dosya_Adi"] = "MB51_26112024"
cols = ["Dosya_Adi"] + [col for col in MB51_26112024.columns if col != "Dosya_Adi"]
MB51_26112024 = MB51_26112024[cols]

MB51_27062025["Dosya_Adi"] = "MB51_27062025"
cols = ["Dosya_Adi"] + [col for col in MB51_27062025.columns if col != "Dosya_Adi"]
MB51_27062025 = MB51_27062025[cols]

MB51_28012025["Dosya_Adi"] = "MB51_28012025"
cols = ["Dosya_Adi"] + [col for col in MB51_28012025.columns if col != "Dosya_Adi"]
MB51_28012025 = MB51_28012025[cols]

MB51_28022025["Dosya_Adi"] = "MB51_28022025"
cols = ["Dosya_Adi"] + [col for col in MB51_28022025.columns if col != "Dosya_Adi"]
MB51_28022025 = MB51_28022025[cols]

MB51_30042025["Dosya_Adi"] = "MB51_30042025"
cols = ["Dosya_Adi"] + [col for col in MB51_30042025.columns if col != "Dosya_Adi"]
MB51_30042025 = MB51_30042025[cols]

MB51_30052025["Dosya_Adi"] = "MB51_30052025"
cols = ["Dosya_Adi"] + [col for col in MB51_30052025.columns if col != "Dosya_Adi"]
MB51_30052025 = MB51_30052025[cols]

MB51_30102024["Dosya_Adi"] = "MB51_30102024"
cols = ["Dosya_Adi"] + [col for col in MB51_30102024.columns if col != "Dosya_Adi"]
MB51_30102024 = MB51_30102024[cols]

MB51_31072025["Dosya_Adi"] = "MB51_31072025"
cols = ["Dosya_Adi"] + [col for col in MB51_31072025.columns if col != "Dosya_Adi"]
MB51_31072025 = MB51_31072025[cols]

# %%
def temizle_ve_cevir(x):
    try:
        return str(int(float(x)))
    except:
        return str(x)

# %%
df_list = [
    MB51_17122024,
    MB51_23092024,
    MB51_26032025,
    MB51_26112024,
    MB51_27062025,
    MB51_28012025,
    MB51_28022025,
    MB51_30042025,
    MB51_30052025,
    MB51_30102024,
    MB51_31072025
]

# %%
# 2️⃣ Tüm df'leri concat ile birleştir
dfbirlesikmb52 = pd.concat(df_list, ignore_index=True)

# %%
dfbirlesikmb52.columns
# Out:
# Index(['Dosya_Adi', 'Unnamed: 0', 'Завод', 'Склад', 'Обозначение склада',
#        'Партия', 'Номер материала', 'RU Tanım', 'TR Tanım', 'На КонтрКачества',
#        'СвобИспользЗапас', 'Базовая ЕИ', 'Ст-ть/своб. испол.', 'Валюта',
#        'Имя 1', 'Вид материала', 'Группа материалов', 'Единица измерения веса',
#        'Ст-ть/контр.кач-ва', 'Стоим. в пути+пер.', 'Ст-ть/огр. испол.',
#        'Краткий текст материала', 'Проект/не проект', 'Заказ на поставку',
#        'Поставщик', 'Заявитель', 'Инвентарный номер', 'Группа закупок',
#        'Наименование группы закупок', 'Наш знак', '№ Позиции ZMB52',
#        '№ Позиции ZMB52 & Заказ на поставку (222)',
#        'цена нетто ME2N по значению 222', 'ед.цены ME2N по 222',
#        'валюта ME2N по 222', 'ИТОГ в валюте', 'Дата документа ME2N по 222',
#        'ИТОГ USD', 'Курс', 'Unnamed: 38', 'Дата ввода ZMB51', 'Unnamed: 40',
#        'Unnamed: 41', 'Стоимость в пути', 'Unnamed: 42', 'Блок', 'Признак ',
#        'Код ККC здания'],
#       dtype='object')

# %%
dfbirlesikmb52.columns
# Out:
# Index(['Dosya_Adi', 'Unnamed: 0', 'Завод', 'Склад', 'Обозначение склада',
#        'Партия', 'Номер материала', 'RU Tanım', 'TR Tanım', 'На КонтрКачества',
#        'СвобИспользЗапас', 'Базовая ЕИ', 'Ст-ть/своб. испол.', 'Валюта',
#        'Имя 1', 'Вид материала', 'Группа материалов', 'Единица измерения веса',
#        'Ст-ть/контр.кач-ва', 'Стоим. в пути+пер.', 'Ст-ть/огр. испол.',
#        'Краткий текст материала', 'Проект/не проект', 'Заказ на поставку',
#        'Поставщик', 'Заявитель', 'Инвентарный номер_old', 'Группа закупок',
#        'Наименование группы закупок', 'Наш знак', '№ Позиции ZMB52',
#        '№ Позиции ZMB52 & Заказ на поставку (222)',
#        'цена нетто ME2N по значению 222', 'ед.цены ME2N по 222',
#        'валюта ME2N по 222', 'ИТОГ в валюте', 'Дата документа ME2N по 222',
#        'ИТОГ USD', 'Курс', 'Unnamed: 38', 'Дата ввода ZMB51', 'Unnamed: 40',
#        'Unnamed: 41', 'Стоимость в пути', 'Unnamed: 42', 'Блок', 'Признак ',
#        'Код ККC здания', 'Материал_Заказ_zmb52', 'inventory_number_2',
#        'зп_Позиция'],
#       dtype='object')

# %%
dfbirlesikmb52["Unnamed: 0"] = dfbirlesikmb52["Unnamed: 0"].apply(temizle_ve_cevir)
dfbirlesikmb52["Партия"] = dfbirlesikmb52["Партия"].apply(temizle_ve_cevir)
dfbirlesikmb52["Номер материала"] = dfbirlesikmb52["Номер материала"].apply(temizle_ve_cevir)
dfbirlesikmb52["Заказ на поставку"] = dfbirlesikmb52["Заказ на поставку"].apply(temizle_ve_cevir)
dfbirlesikmb52["Поставщик"] = dfbirlesikmb52["Поставщик"].apply(temizle_ve_cevir)
dfbirlesikmb52["№ Позиции ZMB52 & Заказ на поставку (222)"] = dfbirlesikmb52["№ Позиции ZMB52 & Заказ на поставку (222)"].apply(temizle_ve_cevir)
dfbirlesikmb52["№ Позиции ZMB52"] = dfbirlesikmb52["№ Позиции ZMB52"].apply(temizle_ve_cevir)

# %%
me2n.head(10)
# Out:
#     ГОД  ﻿Документ закупки  Позиция Индикатор удаления Дата документа  \
# 0  2022         3400013017      280                NaN      1.11.2022
# 1  2022         3400013017      290                NaN      1.11.2022
# 2  2022         3400013007       10                NaN     25.11.2022
# 3  2022         3100000011       20                NaN      2.11.2022
# 4  2022         3400013017      240                NaN      1.11.2022
# 5  2022         3400013003       10                NaN     13.08.2022
# 6  2022         3400013017      270                NaN      1.11.2022
# 7  2022         3400013017      250                NaN      1.11.2022
# 8  2022         3100000013       40                NaN      3.11.2022
# 9  2022         3400013017      180                NaN      1.11.2022
#
#        Наш знак       Ваш код                       Имя поставщика  \
# 0         Муфты         Муфты  2960       TİTAN2 IC İÇTAŞ İNŞAAT A
# 1         Муфты         Муфты  2960       TİTAN2 IC İÇTAŞ İNŞAAT A
# 2      AK-C-284   PO_AK-C-284  1000000797 AKSEL DEKORATİF YAPI SAN
# 3   PO AK-C-187   PO AK-C-187  1000000797 AKSEL DEKORATİF YAPI SAN
# 4         Муфты         Муфты  2960       TİTAN2 IC İÇTAŞ İNŞAAT A
# 5  TSM22-22-870  TSM22-22-870  1000001323 TASELI AKARYAKIT INS. NA
# 6         Муфты         Муфты  2960       TİTAN2 IC İÇTAŞ İNŞAAT A
# 7         Муфты         Муфты  2960       TİTAN2 IC İÇTAŞ İNŞAAT A
# 8   PO АК-C-112   PO АК-C-112  1000000797 AKSEL DEKORATİF YAPI SAN
# 9         Муфты         Муфты  2960       TİTAN2 IC İÇTAŞ İNŞAAT A
#
#        Заявка    Материал  ... Количество в СЕИ Цена нетто  СтоимЗаказа нетто  \
# 0         NaN  4500099234  ...          70000.0       1.93          135100.00
# 1         NaN  4500099244  ...          52181.0       4.51          235336.31
# 2         NaN  4500079969  ...          36000.0       0.17            6120.00
# 3  2200000818  4500125081  ...          25872.0       1.05           27165.60
# 4         NaN  4500096826  ...          25000.0       1.50           37500.00
# 5         NaN  4500000001  ...          23502.0      19.15          450063.30
# 6         NaN  4500099242  ...          15680.0       3.77           59113.60
# 7         NaN  4500099240  ...          15000.0       2.80           42000.00
# 8  2200000773  4500125081  ...          12800.0       1.05           13440.00
# 9         NaN  4500099232  ...          12000.0       1.73           20760.00
#
#    Еще для поставки (стоимость) Валюта  Вид докум. закупки  \
# 0                     135100.00    USD                ZT1C
# 1                     235336.31    USD                ZT1C
# 2                       6120.00    USD                ZT1C
# 3                      27165.60    USD                ZSUP
# 4                      37500.00    USD                ZT1C
# 5                     450063.30    TRY                ZT1C
# 6                      59113.60    USD                ZT1C
# 7                      42000.00    USD                ZT1C
# 8                      13440.00    USD                ZSUP
# 9                      20760.00    USD                ZT1C
#
#                               Краткий текст  Дата поставки  \
# 0                 LOCK NUT LNM24X3,0 DEXTRA     22.12.2022
# 1                      LOCKNUT LNM36 42х4,5     22.12.2022
# 2                                     TALEP     25.11.2022
# 3  Раствор отделочный однокомпонентный на ц     17.12.2022
# 4                          Lock nut CXL20LN     22.12.2022
# 5                                PRO DIESEL     30.08.2022
# 6                LOCK NUT  LNM36x4,0 DEXTRA     22.12.2022
# 7                      LOCKNUT LNM28 33х3,5     22.12.2022
# 8  Раствор отделочный однокомпонентный на ц      9.02.2023
# 9                 LOCK NUT LNM20x2,5 DEXTRA     22.12.2022
#
#    ЕИ заказа на постав. Инвентарный номер
# 0                    ШТ               NaN
# 1                    ШТ               NaN
# 2                    КГ               NaN
# 3                    КГ               NaN
# 4                    ШТ               NaN
# 5                     Л               NaN
# 6                    ШТ               NaN
# 7                    ШТ               NaN
# 8                    КГ               NaN
# 9                    ШТ               NaN
#
# [10 rows x 25 columns]

# %%
me2n.columns
# Out:
# Index(['ГОД', '﻿Документ закупки', 'Позиция', 'Индикатор удаления',
#        'Дата документа', 'Наш знак', 'Ваш код', 'Имя поставщика', 'Заявка',
#        'Материал', 'Наименование RU', 'Наименование TR', 'Объем заказа',
#        'еще поставить (количество)', 'Складская ЕИ', 'Количество в СЕИ',
#        'Цена нетто', 'СтоимЗаказа нетто', 'Еще для поставки (стоимость)',
#        'Валюта', 'Вид докум. закупки', 'Краткий текст', 'Дата поставки',
#        'ЕИ заказа на постав.', 'Инвентарный номер'],
#       dtype='object')

# %%
dfbirlesikmb52["Материал_Заказ_zmb52"] = (
    dfbirlesikmb52["Номер материала"].astype(str) + "_" +
    dfbirlesikmb52["Заказ на поставку"].astype(str)
)

# %%
dfbirlesikmb52["parti+material"] = (
    dfbirlesikmb52["Партия"].astype(str) + "_" +
    dfbirlesikmb52["Номер материала"].astype(str)
)

# %%
me2n["Материал_Заказ_me2n"] = (
    me2n["Материал"].astype(str)+ "_"+
    me2n["﻿Документ закупки"].astype(str)

)

# %%
dfbirlesikmb52["Материал_Заказ_zmb52"] = dfbirlesikmb52["Материал_Заказ_zmb52"].apply(temizle_ve_cevir)
me2n["Материал_Заказ_me2n"] = me2n["Материал_Заказ_me2n"].apply(temizle_ve_cevir)
me2n["Позиция"] = me2n["Позиция"].apply(temizle_ve_cevir)

# %%
dfbirlesikmb52 = dfbirlesikmb52.rename(columns={"Инвентарный номер": "Инвентарный номер_old"})

# %%
map_dict = dict(zip(me2n["Материал_Заказ_me2n"], me2n["Инвентарный номер"]))

# %%
map_dict2 = dict(zip(me2n["Материал_Заказ_me2n"], me2n["Позиция"]))

# %%
# Önce mevcut Инвентарный номер kolonunu yeniden adlandır
dfbirlesikmb52 = dfbirlesikmb52.rename(columns={"Инвентарный номер": "Инвентарный номер_old"})

dfbirlesikmb52["inventory_number_2"] = dfbirlesikmb52["Материал_Заказ_zmb52"].map(map_dict)
dfbirlesikmb52["зп_Позиция"] = dfbirlesikmb52["Материал_Заказ_zmb52"].map(map_dict2)
# Sonuç kontrolü
dfbirlesikmb52[["Материал_Заказ_zmb52", "inventory_number_2","Заказ на поставку","зп_Позиция"]].head()
# Out:
#    Материал_Заказ_zmb52                                 inventory_number_2  \
# 0  45000854643100000256                                                NaN
# 1  45004388583100006400                    AKU.1309.00UTH.0.EW.TB0001(C02)
# 2  45004388533100011520                    AKU.1309.00UTH.0.EW.TB0001(C02)
# 3  45004388723100008448                    AKU.1309.00UTH.0.EW.TB0001(C02)
# 4  45004246973100007424  СП-0902 АЭС АККУЮ СПЕЦИФИКАЦИЯ НА ВСПОМОГАТЕЛЬ...
#
#   Заказ на поставку зп_Позиция
# 0        3100003345         50
# 1        3100010054        100
# 2        3100010054         90
# 3        3100010054        140
# 4        3100008948        560

# %%
# Eğer inventory_number_2 boşsa ve Инвентарный номер_old doluysa, değeri kopyala
dfbirlesikmb52["inventory_number_2"] = dfbirlesikmb52["inventory_number_2"].fillna(
    dfbirlesikmb52["Инвентарный номер_old"]
)

# %%
dfbirlesikmb52[["Номер материала", "Заказ на поставку", "inventory_number_2"]].sample(5)
# Out:
#         Номер материала Заказ на поставку                 inventory_number_2
# 1141801      4500201901               nan                                NaN
# 502739       4500430716        3100009826    AKU.0120.10UJA.0.KM.LC0140(C01)
# 540577       4500079610        3100008599     AKU.0120.17UBZ.0.EW.LH0001(C02
# 224996       4500456152               nan                                NaN
# 717666       4500306748        3100006388  AKU.0120.10UKC.KTN.TM.TB0201(C01)

# %%
# Boş olan satırları filtrele
df_missing = dfbirlesikmb52[dfbirlesikmb52["inventory_number_2"].isna()]

# Random olarak örnek göster (örneğin 10 satır)
df_missing_sample = df_missing.sample(10, random_state=45)  # random_state ile tekrar üretilebilir

# Sadece istediğiniz sütunları göster
df_missing_sample[["Номер материала", "RU Tanım", "Инвентарный номер_old","inventory_number_2","Заказ на поставку"]]
# Out:
#         Номер материала                                           RU Tanım  \
# 223253       4500189167  AKU.0120.10UJA.JMN.YM.TB0102-M37-11JMN12BQ019 P/3
# 305197       4500261274  ГОЛОВКА ТОРЦЕВАЯ УДАРНАЯ ШЕСТИГРАННАЯ 1/2" 15 ...
# 1263034      4500460082  ТРУБОПРОВОД СИСТЕМЫ ПРОМКОНТУРА ПОТРЕБИТЕЛЕЙ Н...
# 681269       4500294743            ЧЕРЕНОК ДЛЯ ЛОПАТЫ L=1450 ММ TRN001 TRN
# 11161        4500450610              10QKC01AA926 КЛАПАН ПРЕДОХРАНИТЕЛЬНЫЙ
# 119553       4500145150  AKU.0120.10UJA.0.KM.LH0002.19/1727.ЭТ2.ОБЛИЦОВ...
# 1113567      4500203114    ДИСК ЛЕПЕСТКОВЫЙ SONNENFLEX 180X22,23 ММ NK P80
# 1174531      4500449614        12JMN32AA409 КЛАПАН ЗАПОРНЫЙ РУЧНОЙ С ЗАМК.
# 794085       4500111051                        ТОНЕР M?NOLTA DR316-AAV70RD
# 539284       4500137925  МАТРИЦА ДЛЯ ОПРЕССОВКИ SFK130ST 130 KN 70 ММ2 ...
#
#         Инвентарный номер_old inventory_number_2 Заказ на поставку
# 223253                    NaN                NaN        3100001438
# 305197                    NaN                NaN        3100006265
# 1263034                   NaN                NaN               nan
# 681269                    NaN                NaN        3100006053
# 11161                     NaN                NaN               nan
# 119553                    NaN                NaN               nan
# 1113567                   NaN                NaN               nan
# 1174531                   NaN                NaN               nan
# 794085                    NaN                NaN        3100001985
# 539284                    NaN                NaN        3100010860

# %%
len(df_missing)
# Out:
# 285829

# %%
zmb51.head(10)
# Out:
#     ГОД ﻿Вид движения Склад  Дата ввода Время ввода Дата документа  \
# 0  2022           101   NaN  23.02.2023    17:13:34     31.12.2022
# 1  2022           101   NaN  24.02.2023    11:24:08     31.07.2022
# 2  2022           101   NaN  24.01.2023    11:54:05     18.09.2022
# 3  2022           101   NaN  19.01.2023    14:10:24      1.12.2022
# 4  2022           101   NaN  25.11.2022    17:03:34     31.07.2022
# 5  2022           101   NaN  25.11.2022    16:23:24     31.07.2022
# 6  2022           101   NaN  25.11.2022    16:33:52     31.07.2022
# 7  2022           101   NaN  30.03.2023    14:40:42     29.08.2022
# 8  2022           101   NaN  25.11.2022    13:58:12     31.07.2022
# 9  2022           101   NaN  25.11.2022    16:04:38     31.07.2022
#
#   Дата проводки  Внутренний заказ  Заказ на поставку  Позиция  ...  \
# 0     1.12.2022               NaN       7.200001e+09       10  ...
# 1     1.12.2022               NaN       7.200001e+09       10  ...
# 2     1.11.2022               NaN       7.200001e+09      100  ...
# 3     1.12.2022               NaN       7.200001e+09       10  ...
# 4    31.07.2022               NaN       7.200001e+09       10  ...
# 5    31.07.2022               NaN       7.200001e+09       10  ...
# 6    31.07.2022               NaN       7.200001e+09       10  ...
# 7     1.12.2022               NaN       3.100001e+09       10  ...
# 8    31.07.2022               NaN       7.200001e+09       10  ...
# 9    31.07.2022               NaN       7.200001e+09       10  ...
#
#    Имя пользователя    БЕ Базовая ЕИ  ГодДокумМатериала Валюта Завод  \
# 0        MBURMAKOVA  2990        NaN               2022    TRY  29A2
# 1        MBURMAKOVA  2990        NaN               2022    TRY  29A2
# 2        ZBONDAREVA  2990        NaN               2022    TRY  29A2
# 3          MVOLKOVA  2990        NaN               2022    TRY  29A2
# 4          MVOLKOVA  2990        NaN               2022    TRY  29A2
# 5          MVOLKOVA  2990        NaN               2022    TRY  29A2
# 6          MVOLKOVA  2990        NaN               2022    TRY  29A2
# 7            NBULUT  2990        NaN               2022    TRY  29B2
# 8          MVOLKOVA  2990        NaN               2022    TRY  29A2
# 9          MVOLKOVA  2990        NaN               2022    TRY  29A2
#
#         Имя 1 Основное средство ЕИ цены заказа ЕИ заказа на постав.
# 0         TSM               NaN             ЕР                   ЕР
# 1         TSM               NaN             ЕР                   ЕР
# 2         TSM               NaN             ЕР                   ЕР
# 3         TSM               NaN             ЕР                   ЕР
# 4         TSM               NaN             ЕР                   ЕР
# 5         TSM               NaN             ЕР                   ЕР
# 6         TSM               NaN             ЕР                   ЕР
# 7  TSM ASSETS             DUMMY             ШТ                   ШТ
# 8         TSM               NaN             ЕР                   ЕР
# 9         TSM               NaN             ЕР                   ЕР
#
# [10 rows x 35 columns]

# %%
zmb51.columns
# Out:
# Index(['ГОД', '﻿Вид движения', 'Склад', 'Дата ввода', 'Время ввода',
#        'Дата документа', 'Дата проводки', 'Внутренний заказ',
#        'Заказ на поставку', 'Позиция', 'Документ материала',
#        'Поз. док. материала', 'Партия', 'Материал', 'Ссылка',
#        'Краткий текст материала', 'Кол-во в ЕИ ввода', 'ЕИ ввода',
#        'Сумма во ВВ', 'Количество', 'Поставщик', 'Накладная',
#        'Текст заголовка документа', 'Заявитель', 'Инвентарный номер',
#        'Имя пользователя', 'БЕ', 'Базовая ЕИ', 'ГодДокумМатериала', 'Валюта',
#        'Завод', 'Имя 1', 'Основное средство', 'ЕИ цены заказа',
#        'ЕИ заказа на постав.'],
#       dtype='object')

# %%
zmb51["Внутренний заказ"] = zmb51["Внутренний заказ"].apply(temizle_ve_cevir)
zmb51["Заказ на поставку"] = zmb51["Заказ на поставку"].apply(temizle_ve_cevir)
zmb51["Позиция"] = zmb51["Позиция"].apply(temizle_ve_cevir)
zmb51["Документ материала"] = zmb51["Документ материала"].apply(temizle_ve_cevir)
zmb51["Партия"] = zmb51["Партия"].apply(temizle_ve_cevir)
zmb51["Материал"] = zmb51["Материал"].apply(temizle_ve_cevir)

# %%
zmb51["parti+material"] = (
    zmb51["Партия"].astype(str) + "_" +
    zmb51["Материал"].astype(str)
)

# %%
map_dict3 = dict(zip(zmb51["parti+material"], zmb51["Инвентарный номер"]))
map_dict4 = dict(zip(zmb51["parti+material"], zmb51["Документ материала"]))
map_dict5 = dict(zip(zmb51["parti+material"], zmb51["Поз. док. материала"]))

# %%
dfbirlesikmb52["inventory_number_2"] = dfbirlesikmb52["inventory_number_2"].fillna(
    dfbirlesikmb52["parti+material"].map(map_dict3)
)

# %%
dfbirlesikmb52.columns
# Out:
# Index(['Dosya_Adi', 'Unnamed: 0', 'Завод', 'Склад', 'Обозначение склада',
#        'Партия', 'Номер материала', 'RU Tanım', 'TR Tanım', 'На КонтрКачества',
#        'СвобИспользЗапас', 'Базовая ЕИ', 'Ст-ть/своб. испол.', 'Валюта',
#        'Имя 1', 'Вид материала', 'Группа материалов', 'Единица измерения веса',
#        'Ст-ть/контр.кач-ва', 'Стоим. в пути+пер.', 'Ст-ть/огр. испол.',
#        'Краткий текст материала', 'Проект/не проект', 'Заказ на поставку',
#        'Поставщик', 'Заявитель', 'Инвентарный номер_old', 'Группа закупок',
#        'Наименование группы закупок', 'Наш знак', '№ Позиции ZMB52',
#        '№ Позиции ZMB52 & Заказ на поставку (222)',
#        'цена нетто ME2N по значению 222', 'ед.цены ME2N по 222',
#        'валюта ME2N по 222', 'ИТОГ в валюте', 'Дата документа ME2N по 222',
#        'ИТОГ USD', 'Курс', 'Unnamed: 38', 'Дата ввода ZMB51', 'Unnamed: 40',
#        'Unnamed: 41', 'Стоимость в пути', 'Unnamed: 42', 'Блок', 'Признак ',
#        'Код ККC здания', 'Материал_Заказ_zmb52', 'inventory_number_2',
#        'зп_Позиция', 'parti+material'],
#       dtype='object')

# %%
dfbirlesikmb52["Заказ на поставку"] = dfbirlesikmb52["Заказ на поставку"].fillna(
    dfbirlesikmb52["parti+material"].map(map_dict4)
)

# %%
dfbirlesikmb52["зп_Позиция"] = dfbirlesikmb52["зп_Позиция"].fillna(
    dfbirlesikmb52["parti+material"].map(map_dict5)
)

# %%
dfbirlesikmb52["inventory_number_2"] = dfbirlesikmb52["inventory_number_2"].fillna(
    dfbirlesikmb52["Материал_Заказ_zmb52"].map(map_dict2)
)

# %%
import pandas as pd

# Dosya isimleri
file_names = [
    "MB51_17122024", "MB51_23092024", "MB51_26032025", "MB51_26112024",
    "MB51_27062025", "MB51_28012025", "MB51_28022025", "MB51_30042025",
    "MB51_30052025", "MB51_30102024", "MB51_31072025"
]

# Her dosya için df oluştur ve Excel olarak kaydet
for file in file_names:
    # df oluştur
    df_temp = dfbirlesikmb52[dfbirlesikmb52["Dosya_Adi"] == file].copy()

    # Değişkene atamak için globals kullanabiliriz
    globals()[f"{file}z"] = df_temp

    # Excel olarak kaydet
    output_name = f"{file}_filtered.xlsx"
    df_temp.to_excel(output_name, index=False)
    print(f"{output_name} kaydedildi.")
# Out:
# MB51_17122024_filtered.xlsx kaydedildi.
